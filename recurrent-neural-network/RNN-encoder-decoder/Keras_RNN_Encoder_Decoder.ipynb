# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
np.random.seed(0)

# %%
# Data Preparation

# %%
def load_data(file_path):
    tokenizer = Tokenizer(filters="")
    whole_texts = []
    for line in open(file_path, encoding='utf-8'):
        whole_texts.append("<s> " + line.strip() + " </s>")
        
    tokenizer.fit_on_texts(whole_texts)
    
    return tokenizer.texts_to_sequences(whole_texts), tokenizer

# %%
X_train, tokenizer_en = load_data('/root/userspace/private/RNN/train.en')
Y_train, tokenizer_ja = load_data('/root/userspace/private/RNN/train.ja')

# %%
en_vocab_size = len(tokenizer_en.word_index) + 1
jp_vocab_size = len(tokenizer_ja.word_index) + 1

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X_train,
                                                                Y_train,
                                                                test_size=0.02,
                                                                random_state=42)

# %%
X_train = pad_sequences(X_train, padding='post')
Y_train = pad_sequences(Y_train, padding='post')

# %%
dim_seq_input = len(X_train[0])
dim_seq_output = len(Y_train[0])

# %%
# Building a model

# %%
class RNNEncoderDecoder(object):
    def __init__(self, dim_seq_input, dim_input, dim_seq_output, dim_output, dim_emb, dim_hid, dim_vocab_input, dim_vocab_output):
        self._model = None
        self._model_validation_encoder = None
        self._model_validation_decoder = None
        
        self.dim_seq_input = dim_seq_input
        self.dim_input = dim_input
        
        self.dim_seq_output = dim_seq_output
        self.dim_output = dim_output
        
        self.dim_emb = dim_emb
        self.dim_hid = dim_hid
        
        self.dim_vocab_input = dim_vocab_input
        self.dim_vocab_output = dim_vocab_output
        
        self._encoder_inputs = None
        self._encoder_states = None
        
        self._decoder_embedding = None
        self._decoder_lstm = None
        self._decoder_dense = None
        
    def inference(self):
        from keras.models import Model
        from keras.layers import Input, Embedding, Dense, LSTM

        # Encoder
        ## Input Layer
        self._encoder_inputs = Input(shape=(self.dim_seq_input,))

        ## Embedding Layer
        encoder_embedded = Embedding(self.dim_vocab_input, self.dim_emb, mask_zero=True)(self._encoder_inputs) # (dim_seq_input,)->(dim_seq_input, dim_emb)
        
        ## LSTM Layer
        _, *(self._encoder_states) = LSTM(self.dim_hid, return_state=True)(encoder_embedded)  # (dim_seq_input, dim_emb)->(dim_seq_input, dim_hid)

        # Decoder
        ## Instance
        self._decoder_embedding = Embedding(self.dim_vocab_output, self.dim_emb)
        self._decoder_lstm = LSTM(self.dim_hid, return_sequences=True, return_state=True)
        self._decoder_dense = Dense(self.dim_vocab_output, activation='softmax')
        
        ## Input Layer
        decoder_inputs = Input(shape=(self.dim_seq_output,))

        ## Embedding Layer
        decoder_embedded = self._decoder_embedding(decoder_inputs)  # (dim_seq_output,)->(dim_seq_output, dim_emb)
        
        ## LSTM Layer       
        decoder_outputs, _, _ = self._decoder_lstm(decoder_embedded, initial_state=self._encoder_states) # (dim_seq_output, dim_emb)->(dim_seq_output, dim_hid)
        
        ## Output Layer
        predictions = self._decoder_dense(decoder_outputs) # shape: (dim_seq_output, dim_hid)->(dim_seq_output, dim_vocab_output)
        
        return Model([self._encoder_inputs, decoder_inputs], predictions)       
 
    def inference_validation(self):
        from keras.models import Model
        from keras.layers import Input        

        # Encoder
        model_encoder = Model(self._encoder_inputs, self._encoder_states)

        # Decoder
        ## Input Layer
        decoder_inputs = Input(shape=(1,))

        ## Embedding Layer
        decoder_embedded = self._decoder_embedding(decoder_inputs) 

        ## LSTM Layer
        decoder_states_inputs = [Input(shape=(self.dim_hid,)), Input(shape=(self.dim_hid,))]
        decoder_outputs, *decoder_states = self._decoder_lstm(decoder_embedded, initial_state=decoder_states_inputs)

        ## Output Layer
        predictions = self._decoder_dense(decoder_outputs)

        model_decoder = Model([decoder_inputs] + decoder_states_inputs, [predictions] + decoder_states)

        return model_encoder, model_decoder
               
    def predict(self, X, bos_eos, max_output_length = 1000):
        states_value = self._model_validation_encoder.predict(X)

        target_seq = np.array(bos_eos[0])
        output_seq= bos_eos[0][:]

        while True:
            output_tokens, *states_value = self._model_validation_decoder.predict([target_seq] + states_value)
            sampled_token_index = [np.argmax(output_tokens[0, -1, :])]
            output_seq += sampled_token_index

            if (sampled_token_index == bos_eos[1] or len(output_seq) > max_output_length):
                break

            target_seq = np.array(sampled_token_index)

        return output_seq

    def compile(self):
        self._model = self.inference()
        self._model.compile(loss='sparse_categorical_crossentropy',
                            optimizer='rmsprop',
                            metrics=['accuracy'])
        
        self._model_validation_encoder, self._model_validation_decoder = self.inference_validation()
        
    def fit(self, X_train, Y_train, epochs, batch_size, verbose=1):
        train_target = np.hstack((Y_train[:, 1:], np.zeros((len(Y_train),1), dtype=np.int32)))
        
        history = self._model.fit([X_train, Y_train],
                                  np.expand_dims(train_target, -1),
                                  batch_size=batch_size,
                                  epochs=epochs,
                                  verbose=verbose,
                                  validation_split=0.2)
        
        return history.history
    
    def show_graph(self):
        return model_to_dot(self._model).create(prog='dot', format='svg')

# %%
model = RNNEncoderDecoder(dim_seq_input=dim_seq_input,
                          dim_input=None,
                          dim_seq_output=dim_seq_output,
                          dim_output=None,
                          dim_emb=256,
                          dim_hid=256,
                          dim_vocab_input=en_vocab_size,
                          dim_vocab_output=jp_vocab_size)

# %%
model.compile()

# %%
SVG(model.show_graph())

# %%
# Training the model

# %%
history = model.fit(X_train,
                    Y_train,
                    epochs=15,
                    batch_size=128)
# Out:
# Train on 39200 samples, validate on 9800 samples
# Epoch 1/15
# 39200/39200 [==============================] - 107s 3ms/step - loss: 2.9554 - acc: 0.4774 - val_loss: 2.3073 - val_acc: 0.5784
# Epoch 2/15
# 39200/39200 [==============================] - 104s 3ms/step - loss: 2.0823 - acc: 0.6179 - val_loss: 1.9541 - val_acc: 0.6415
# Epoch 3/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.8104 - acc: 0.6613 - val_loss: 1.7654 - val_acc: 0.6697
# Epoch 4/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.6444 - acc: 0.6860 - val_loss: 1.6529 - val_acc: 0.6889
# Epoch 5/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.5161 - acc: 0.7050 - val_loss: 1.5522 - val_acc: 0.7021
# Epoch 6/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.4082 - acc: 0.7219 - val_loss: 1.4832 - val_acc: 0.7131
# Epoch 7/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.3141 - acc: 0.7376 - val_loss: 1.4181 - val_acc: 0.7244
# Epoch 8/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.2319 - acc: 0.7518 - val_loss: 1.3748 - val_acc: 0.7313
# Epoch 9/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.1604 - acc: 0.7644 - val_loss: 1.3326 - val_acc: 0.7392
# Epoch 10/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.0966 - acc: 0.7759 - val_loss: 1.3064 - val_acc: 0.7439
# Epoch 11/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 1.0411 - acc: 0.7860 - val_loss: 1.2898 - val_acc: 0.7465
# Epoch 12/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 0.9899 - acc: 0.7953 - val_loss: 1.2759 - val_acc: 0.7485
# Epoch 13/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 0.9425 - acc: 0.8049 - val_loss: 1.2625 - val_acc: 0.7510
# Epoch 14/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 0.8998 - acc: 0.8136 - val_loss: 1.2575 - val_acc: 0.7533
# Epoch 15/15
# 39200/39200 [==============================] - 103s 3ms/step - loss: 0.8593 - acc: 0.8213 - val_loss: 1.2562 - val_acc: 0.7543

# %%
model._model.save('/root/userspace/private/RNN/_model.h5')
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
model._model_validation_encoder.save('/root/userspace/private/RNN/_model_validation_encoder.h5')

# %%
model._model_validation_decoder.save('/root/userspace/private/RNN/_model_validation_decoder.h5')
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/engine/topology.py:2344: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'input_4:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'input_5:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
# Confirming the result

# %%
def show_graph(history, key, title=None, xlabel=None, ylabel=None, yscale=None):
    fig = plt.figure(figsize=(16, 4))
    ax = fig.add_subplot(111)
    ax.plot(history[key])

    if title:
        ax.set_title(title)
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel:
        ax.set_ylabel(ylabel)

    if yscale:
        plt.yscale(yscale)

    plt.show()

# %%
show_graph(history, 'loss', 'Validation Loss', 'Iteration', 'Validation Loss', 'log')

# %%
show_graph(history, 'acc', 'Validation Accuracy', 'Iteration', 'Validation Accuracy', 'log')

# %%
detokenizer_en = dict(map(reversed, tokenizer_en.word_index.items()))
detokenizer_ja = dict(map(reversed, tokenizer_ja.word_index.items()))

# %%
bos_eos = tokenizer_ja.texts_to_sequences(["<s>", "</s>"])

# %%
from nltk.translate.bleu_score import sentence_bleu

def compute_bleu(refs, preds):
    return np.mean([sentence_bleu(r, p, emulate_multibleu=True) for r, p in zip(refs, preds)])

# %%
for text_no in range(len(X_validation)):
    inp = [detokenizer_en[i] for i in X_validation[text_no][1:-1]]
    ref = [detokenizer_ja[i] for i in Y_validation[text_no][1:-1]]
    
    input_seq = pad_sequences([X_validation[text_no]], dim_seq_input, padding='post')
    pred = [detokenizer_ja[i] for i in model.predict(input_seq, bos_eos)[1:-1]]
    
    bleu = sentence_bleu(ref, pred)
    
    if bleu > 0.0:
        print('text_no: {0}'.format(text_no))
        print('元の文: {0}'.format(inp))
        print('正解文: {0}'.format(ref))
        print('生成文: {0}'.format(pred))
        print('bleu: {0}\n'.format(bleu))
# Out:
# /usr/local/lib/python3.5/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# text_no: 0
# 元の文: ['you', 'may', 'extend', 'your', 'stay', 'in', 'tokyo', '.']
# 正解文: ['東京', '滞在', 'を', '延ば', 'し', 'て', 'も', 'い', 'い', 'で', 'す', 'よ', '。']
# 生成文: ['東京', 'に', 'は', '東京', 'へ', '行', 'っ', 'て', 'も', 'い', 'い', 'で', 'す', 'よ', '。']
# bleu: 0.8265168183793802
#
# text_no: 1
# 元の文: ['i', 'study', 'at', 'school', '.']
# 正解文: ['私', 'は', '学校', 'で', '勉強', 'する', '。']
# 生成文: ['私', 'は', '学校', 'で', '学校', 'を', '通', 'っ', 'て', 'い', 'る', '。']
# bleu: 0.8034284189446518
#
# text_no: 2
# 元の文: ['i', 'always', 'brush', 'my', 'coat', 'when', 'i', 'come', 'home', '.']
# 正解文: ['私', 'は', '帰宅', 'する', 'と', 'いつ', 'も', 'コート', 'に', 'ブラシ', 'を', 'かけ', 'る', '。']
# 生成文: ['私', 'は', 'いつ', 'も', '家', 'に', 'い', 'る', 'とき', 'に', 'タクシー', 'を', '使', 'う', '。']
# bleu: 0.8545740127924681
#
# text_no: 3
# 元の文: ['your', 'mother', 'has', 'made', 'you', 'what', 'you', 'are', '.']
# 正解文: ['君', 'が', '今日', 'あ', 'る', 'の', 'は', 'お', '母', 'さん', 'の', 'おかげ', 'だ', '。']
# 生成文: ['あなた', 'の', 'お', '母', 'さん', 'が', '君', 'の', '考え', 'を', 'し', 'た', 'もの', 'だ', '。']
# bleu: 0.8265168183793802
#
# text_no: 4
# 元の文: ['don', "'t", 'stand', 'in', 'my', 'way', '.']
# 正解文: ['私', 'の', '邪魔', 'を', 'する', 'な', '。']
# 生成文: ['私', 'の', '気', 'に', 'は', 'かま', 'わ', 'な', 'い', '。']
# bleu: 0.7952707287670506
#
# text_no: 5
# 元の文: ['debbie', ',', 'is', 'your', 'school', 'near', 'here', '?']
# 正解文: ['デビー', '、', '学校', 'は', '近く', 'な', 'の', '。']
# 生成文: ['明日', 'の', '学校', 'の', 'どの', 'バス', 'で', 'す', 'か', '。']
# bleu: 0.668740304976422
#
# text_no: 6
# 元の文: ['do', 'you', 'travel', 'a', 'lot', '?']
# 正解文: ['よく', '旅行', 'を', 'し', 'ま', 'す', 'か', '。']
# 生成文: ['旅行', 'は', 'あ', 'り', 'ま', 'す', 'か', '。']
# bleu: 0.8408964152537145
#
# text_no: 7
# 元の文: ['you', 'look', 'nice', 'in', 'that', 'dress', '.']
# 正解文: ['その', 'ドレス', 'を', '着', 'る', 'と', '素敵', 'よ', '。']
# 生成文: ['君', 'は', 'とても', '親切', 'に', 'し', 'て', 'い', 'る', 'ん', 'だ', 'ね', '。']
# bleu: 0.6262844962765469
#
# text_no: 8
# 元の文: ['to', 'all', 'appearance', 'it', 'is', 'true', '.']
# 正解文: ['それ', 'は', '本当', 'ら', 'し', 'く', '見え', 'る', '。']
# 生成文: ['それ', 'は', '本当', 'に', 'も', '本当', 'だ', '。']
# bleu: 0.7071067811865476
#
# text_no: 9
# 元の文: ['this', 'is', 'more', 'expensive', 'than', 'that', '.']
# 正解文: ['これ', 'は', 'あれ', 'より', 'も', '値段', 'が', 'たか', 'い', '。']
# 生成文: ['これ', 'は', 'これ', 'より', 'も', '高', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 10
# 元の文: ['could', 'you', 'solve', 'the', 'problem', '?']
# 正解文: ['君', 'は', 'その', '問題', 'を', '解', 'く', 'こと', 'が', 'でき', 'ま', 'し', 'た', 'か', '。']
# 生成文: ['その', '問題', 'を', '解', 'い', 'て', 'くださ', 'い', 'ま', 'せ', 'ん', 'か', '。']
# bleu: 0.7875110621102679
#
# text_no: 11
# 元の文: ['the', 'medicine', 'did', 'wonders', 'for', 'his', 'health', '.']
# 正解文: ['その', '薬', 'は', '彼', 'の', '体', 'に', '驚', 'く', 'ほど', 'よく', '効', 'い', 'た', '。']
# 生成文: ['その', '薬', 'は', '彼', 'は', '健康', 'に', 'しま', 'っ', 'た', '。']
# bleu: 0.8593887047640296
#
# text_no: 12
# 元の文: ['can', 'you', 'wait', 'until', 'i', 'make', 'up', 'my', 'face', '?']
# 正解文: ['お', '化粧', 'する', 'まで', '待', 'っ', 'て', 'て', '。']
# 生成文: ['私', 'が', '見え', 'る', 'まで', '待', 'ち', 'ま', 'しょ', 'う', '。']
# bleu: 0.7765453555044466
#
# text_no: 13
# 元の文: ['i', 'passed', 'on', 'the', 'job', 'to', 'him', '.']
# 正解文: ['その', '仕事', 'を', '彼', 'に', 'ゆず', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '仕事', 'に', '満足', 'し', 'て', 'や', 'っ', 'た', '。']
# bleu: 0.8210967436686386
#
# text_no: 14
# 元の文: ['in', 'a', 'word', ',', 'i', 'think', 'he', "'s", 'a', 'fool', '.']
# 正解文: ['一言', 'で', '言', 'え', 'ば', '、', '彼', 'は', '馬鹿', 'だ', 'と', '思', 'い', 'ま', 'す', '。']
# 生成文: ['考え', 'る', 'と', 'い', 'う', 'こと', 'は', '彼', 'に', 'と', 'っ', 'て', '馬鹿', 'だ', '。']
# bleu: 0.7952707287670506
#
# text_no: 15
# 元の文: ['i', 'walked', 'the', 'whole', 'way', 'to', 'the', 'station', '.']
# 正解文: ['ぼく', 'は', '駅', 'まで', '全部', '歩', 'い', 'て', 'い', 'っ', 'た', '。']
# 生成文: ['私', 'は', '駅', 'まで', '歩', 'い', 'て', '行', 'っ', 'た', '。']
# bleu: 0.9234732618882052
#
# text_no: 16
# 元の文: ['it', 'is', 'not', 'clear', 'when', 'the', 'man', 'was', 'born', '.']
# 正解文: ['その', '男', 'が', 'いつ', '生まれ', 'た', 'の', 'か', 'はっきり', 'し', 'て', 'い', 'な', 'い', '。']
# 生成文: ['彼', 'が', '生まれ', 'た', 'の', 'は', 'どこ', 'で', 'も', 'な', 'く', 'て', 'も', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 17
# 元の文: ['he', 'has', 'a', 'kind', 'heart', '.']
# 正解文: ['彼', 'は', '優し', 'い', '心', 'の', '持ち主', 'だ', '。']
# 生成文: ['彼', 'は', '親切', 'な', '人', 'だ', '。']
# bleu: 0.8694417438899827
#
# text_no: 18
# 元の文: ['may', 'i', 'start', 'eating', 'now', '?']
# 正解文: ['もう', '食べ', '始め', 'て', 'も', 'い', 'い', 'で', 'す', 'か', '。']
# 生成文: ['今', '出発', 'し', 'て', 'も', 'い', 'い', 'で', 'す', 'か', '。']
# bleu: 0.8931539818068694
#
# text_no: 19
# 元の文: ['i', 'used', 'to', 'a', 'lot', '.']
# 正解文: ['昔', 'は', 'よ', 'く', 'し', 'た', '。']
# 生成文: ['私', 'は', 'たくさん', 'の', '生活', 'を', 'し', 'た', '。']
# bleu: 0.816496580927726
#
# text_no: 20
# 元の文: ['he', 'is', 'almost', 'always', 'at', 'home', '.']
# 正解文: ['彼', 'は', 'ほとんど', 'いつ', 'も', '家', 'に', 'い', 'る', '。']
# 生成文: ['彼', 'は', 'いつ', 'も', '家', 'に', 'い', 'る', '。']
# bleu: 0.9709835434146469
#
# text_no: 21
# 元の文: ['he', 'made', 'his', 'son', 'a', 'chair', '.']
# 正解文: ['彼', 'は', '息子', 'に', '椅子', 'を', '作', 'っ', 'て', 'や', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '息子', 'を', '息子', 'に', 'や', 'っ', 'た', '。']
# bleu: 0.9457416090031758
#
# text_no: 22
# 元の文: ['when', 'my', 'mother', 'was', 'young', ',', 'she', 'was', 'very', 'beautiful', '.']
# 正解文: ['母', 'は', '若', 'い', 'とき', '、', 'とても', '美し', 'かっ', 'た', '。']
# 生成文: ['母', 'は', '若', 'い', 'の', 'で', '、', 'とても', '幸せ', 'だっ', 'た', '。']
# bleu: 0.8739351325046805
#
# text_no: 23
# 元の文: ['he', 'is', 'by', 'far', 'the', 'best', 'student', '.']
# 正解文: ['彼', 'は', '誰', 'より', 'も', '良', 'く', '出き', 'る', '生徒', 'だ', '。']
# 生成文: ['彼', 'は', 'クラス', 'で', '一番', '背', 'が', '高', 'い', '。']
# bleu: 0.7400828044922853
#
# text_no: 24
# 元の文: ['i', 'do', 'not', 'want', 'to', 'reply', 'to', 'his', 'letter', '.']
# 正解文: ['私', 'は', '彼', 'の', '手紙', 'に', '返事', 'を', '出', 'し', 'た', 'く', 'な', 'い', '。']
# 生成文: ['私', 'は', '彼', 'に', '手紙', 'を', '書', 'か', 'な', 'い', 'つもり', 'で', 'な', 'い', '。']
# bleu: 0.8545740127924681
#
# text_no: 25
# 元の文: ['there', 'is', 'a', 'lot', 'of', 'traffic', 'on', 'that', 'street', '.']
# 正解文: ['あの', 'とおり', 'は', '交通', '量', 'が', '多', 'い', '。']
# 生成文: ['その', '通り', 'に', 'は', '交通', 'が', '多', 'い', '。']
# bleu: 0.8633400213704505
#
# text_no: 26
# 元の文: ['the', 'mother', 'kissed', 'her', 'baby', '.']
# 正解文: ['母親', 'は', '赤ちゃん', 'に', 'キス', 'し', 'た', '。']
# 生成文: ['母', 'は', '子供', 'たち', 'を', '思い出', 'し', 'た', '。']
# bleu: 0.8633400213704505
#
# text_no: 27
# 元の文: ['cars', 'keep', 'to', 'the', 'left', 'in', 'japan', '.']
# 正解文: ['日本', 'で', 'は', '、', '自動', '車', 'は', '左側', '通行', 'で', 'す', '。']
# 生成文: ['車', 'を', '日本', 'で', '車', 'を', '洗', 'っ', 'て', 'は', 'いけ', 'な', 'い', '。']
# bleu: 0.7311104457090247
#
# text_no: 28
# 元の文: ['most', 'students', 'like', 'sports', '.']
# 正解文: ['たいてい', 'の', '学生', 'は', 'スポーツ', 'が', '好き', 'だ', '。']
# 生成文: ['日本', 'で', 'は', '野球', 'が', '好き', 'で', 'す', '。']
# bleu: 0.7598356856515925
#
# text_no: 29
# 元の文: ['you', 'need', 'not', 'have', 'woken', 'me', 'up', '.']
# 正解文: ['起こ', 'し', 'て', 'くれ', 'る', '必要', 'は', 'な', 'かっ', 'た', 'の', 'に', '。']
# 生成文: ['私', 'は', '君', 'に', 'は', '親切', 'に', 'も', 'し', 'な', 'い', '。']
# bleu: 0.8034284189446518
#
# text_no: 30
# 元の文: ['she', 'is', 'two', 'years', 'senior', 'to', 'you', '.']
# 正解文: ['彼女', 'は', 'あなた', 'より', '２', '歳', '年上', 'で', 'あ', 'る', '。']
# 生成文: ['彼女', 'は', 'あなた', 'より', '２', '歳', '年上', 'だ', '。']
# bleu: 0.816496580927726
#
# text_no: 31
# 元の文: ['i', 'am', 'short', 'of', 'pocket', 'money', '.']
# 正解文: ['私', 'は', '小遣い', 'が', '不足', 'し', 'て', 'い', 'る', '。']
# 生成文: ['私', 'は', '金', 'が', '不足', 'し', 'て', 'い', 'る', '。']
# bleu: 0.9457416090031758
#
# text_no: 32
# 元の文: ['it', 'was', 'clear', 'that', 'he', 'went', 'there', '.']
# 正解文: ['彼', 'が', 'そこ', 'へ', '行', 'っ', 'た', 'の', 'は', '明らか', 'だっ', 'た', '。']
# 生成文: ['彼', 'が', 'そこ', 'へ', '行', 'っ', 'た', 'の', 'は', 'もう', '一', '度', 'それ', 'で', 'す', '。']
# bleu: 0.8660254037844387
#
# text_no: 33
# 元の文: ['how', 'did', 'he', 'take', 'the', 'news', '?']
# 正解文: ['彼', 'は', 'その', '知らせ', 'を', 'どう', '受け取', 'っ', 'た', 'の', '。']
# 生成文: ['彼', 'は', 'その', 'ニュース', 'を', 'どう', '思', 'っ', 'た', 'の', 'で', 'す', 'か', '。']
# bleu: 0.8408964152537145
#
# text_no: 34
# 元の文: ['that', 'is', 'the', 'building', 'where', 'my', 'father', 'works', '.']
# 正解文: ['あれ', 'は', '私', 'の', '父', 'が', '働', 'い', 'て', 'い', 'る', '建物', 'で', 'あ', 'る', '。']
# 生成文: ['あれ', 'が', '私', 'の', '車', 'で', 'す', '所', 'で', 'す', '。']
# bleu: 0.8210967436686386
#
# text_no: 35
# 元の文: ['i', 'ought', 'to', 'have', 'made', 'a', 'hotel', 'reservation', 'earlier', '.']
# 正解文: ['もっと', '早', 'く', 'ホテル', 'の', '予約', 'を', 'し', 'て', 'お', 'く', 'ん', 'だっ', 'た', '。']
# 生成文: ['私', 'は', '、', '、', '東京', 'を', '行', 'く', 'べ', 'き', 'だっ', 'た', 'の', 'に', '。']
# bleu: 0.7598356856515925
#
# text_no: 36
# 元の文: ['he', 'walked', 'up', 'and', 'down', 'the', 'room', '.']
# 正解文: ['彼', 'は', '部屋', 'の', '中', 'を', 'あちこち', '歩', 'い', 'た', '。']
# 生成文: ['彼', 'は', '部屋', 'を', '掃除', 'し', 'た', '。']
# bleu: 0.8891397050194614
#
# text_no: 37
# 元の文: ['not', 'only', 'the', 'student', 'but', 'their', 'teacher', 'is', 'looking', 'forward', 'to', 'holiday', '.']
# 正解文: ['生徒', 'だけ', 'で', 'な', 'く', '先生', 'も', '休暇', 'を', '待ち望', 'ん', 'で', 'い', 'る', '。']
# 生成文: ['先生', 'が', '来', 'る', 'の', 'は', '、', '誰', 'も', 'その', '計画', 'を', '実行', 'し', 'た', 'く', 'な', 'い', '。']
# bleu: 0.7790872728179328
#
# text_no: 38
# 元の文: ['he', 'is', 'as', 'tall', 'as', 'my', 'father', '.']
# 正解文: ['彼', 'は', '私', 'の', '父', 'と', '同じ', '位', 'の', '身長', 'で', 'す', '。']
# 生成文: ['彼', 'は', '私', 'の', '父', 'と', '同じ', 'くらい', '背', 'が', '高', 'い', '。']
# bleu: 0.8566209113168688
#
# text_no: 39
# 元の文: ['it', 'has', 'been', 'raining', 'since', 'last', 'sunday', '.']
# 正解文: ['先週', 'の', '日曜', '日', 'から', '雨', 'が', '降', 'り', '続け', 'て', 'い', 'る', '。']
# 生成文: ['先週', 'の', '日曜', '日', 'から', 'ずっと', '雨', 'が', '降', 'っ', 'て', 'い', 'る', '。']
# bleu: 0.8954237688029468
#
# text_no: 40
# 元の文: ['she', 'babbled', 'out', 'the', 'secret', 'to', 'her', 'friend', '.']
# 正解文: ['彼女', 'は', 'その', '秘密', 'を', '友達', 'に', 'もら', 'し', 'た', '。']
# 生成文: ['彼女', 'は', 'その', '事実', 'を', '聞', 'い', 'て', '喜', 'ん', 'だ', '。']
# bleu: 0.7071067811865476
#
# text_no: 41
# 元の文: ['i', 'lead', 'a', 'busy', 'life', '.']
# 正解文: ['多忙', 'な', '生活', 'を', '送', 'る', '。']
# 生成文: ['私', 'は', '命', 'が', '大好き', 'だ', '。']
# bleu: 0.6147881529512643
#
# text_no: 42
# 元の文: ['have', 'you', 'ever', 'been', 'to', 'that', 'village', '?']
# 正解文: ['君', 'は', 'あの', '村', 'へ', '行', 'っ', 'た', 'こと', 'が', 'あ', 'り', 'ま', 'す', 'か', '。']
# 生成文: ['あの', '村', 'に', 'は', 'どう', 'し', 'た', 'の', 'か', '。']
# bleu: 0.8801117367933934
#
# text_no: 43
# 元の文: ['i', 'don', "'t", 'like', 'cheese', 'very', 'much', '.']
# 正解文: ['私', 'は', 'あまり', 'チーズ', 'が', '好き', 'で', 'は', 'な', 'い', '。']
# 生成文: ['私', 'は', 'あまり', '好き', 'で', 'は', 'な', 'い', '。']
# bleu: 0.9036020036098448
#
# text_no: 44
# 元の文: ['john', 'is', 'better', 'loved', 'than', 'his', 'father', '.']
# 正解文: ['ジョン', 'は', '父親', '以上', 'に', '愛', 'さ', 'れ', 'て', 'い', 'る', '。']
# 生成文: ['ジョン', 'は', '父親', 'の', '世話', 'を', 'よく', 'し', 'て', 'い', 'る', '。']
# bleu: 0.8034284189446518
#
# text_no: 45
# 元の文: ['please', 'close', 'the', 'door', '.']
# 正解文: ['その', '戸', 'を', '閉め', 'て', '下さ', 'い', '。']
# 生成文: ['ドア', 'を', '閉め', 'て', 'くださ', 'い', '。']
# bleu: 0.8694417438899827
#
# text_no: 46
# 元の文: ['can', 'i', 'be', 'of', 'any', 'assistance', 'to', 'you', '?']
# 正解文: ['あなた', 'の', '助力', 'に', '慣れ', 'る', 'で', 'しょ', 'う', 'か', '。']
# 生成文: ['私', 'は', '何', 'を', 'も', '喜', 'ば', 'せ', 'る', 'の', '。']
# bleu: 0.7226568811456053
#
# text_no: 47
# 元の文: ['honesty', 'doesn', "'t", 'pay', '.']
# 正解文: ['正直', '者', 'が', '馬鹿', 'を', '見', 'る', '。']
# 生成文: ['正直', 'は', '誰', 'で', 'も', 'や', 'り', 'たが', 'る', '。']
# bleu: 0.668740304976422
#
# text_no: 48
# 元の文: ['this', 'coat', 'fits', 'you', '.']
# 正解文: ['この', 'コート', 'は', '君', 'に', 'ぴったり', 'だ', '。']
# 生成文: ['この', 'コート', 'は', '、', '君', 'と', '合', 'う', '。']
# bleu: 0.7598356856515925
#
# text_no: 49
# 元の文: ['i', 'have', 'no', 'great', 'belief', 'in', 'my', 'doctor', '.']
# 正解文: ['私', 'は', '自分', 'の', '医者', 'を', 'ほとんど', '信頼', 'し', 'て', 'い', 'ま', 'せ', 'ん', '。']
# 生成文: ['私', 'は', '医者', 'の', '世話', 'を', 'し', 'て', 'い', 'な', 'い', '。']
# bleu: 0.9036020036098448
#
# text_no: 50
# 元の文: ['it', 'has', 'a', 'value', 'all', 'its', 'own', '.']
# 正解文: ['それ', 'に', 'は', 'それ', 'なり', 'の', '価値', 'が', 'あ', 'る', '。']
# 生成文: ['それ', 'は', '自分', 'で', 'も', '重要', 'な', 'もの', 'で', 'あ', 'る', '。']
# bleu: 0.8034284189446518
#
# text_no: 51
# 元の文: ['he', 'tried', 'opening', 'the', 'door', '.']
# 正解文: ['彼', 'は', '試し', 'に', 'ドア', 'を', '開け', 'た', '。']
# 生成文: ['彼', 'は', 'ドア', 'を', '開け', 'た', 'まま', 'に', 'し', 'た', '。']
# bleu: 0.8931539818068694
#
# text_no: 52
# 元の文: ['he', 'got', 'angry', 'at', 'being', 'insulted', '.']
# 正解文: ['彼', 'は', '侮辱', 'さ', 'れ', 'て', '腹', 'を', '立て', 'た', '。']
# 生成文: ['彼', 'は', '怒', 'っ', 'た', 'の', 'を', '見', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 53
# 元の文: ['this', 'is', 'the', 'hat', 'i', "'ve", 'been', 'looking', 'for', '.']
# 正解文: ['これ', 'が', '私', 'が', 'ずっと', '探', 'し', 'て', 'い', 'た', '帽子', 'で', 'す', '。']
# 生成文: ['これ', 'が', '私', 'の', '目', 'に', 'し', 'て', 'い', 'る', '年', 'で', 'す', '。']
# bleu: 0.8694417438899827
#
# text_no: 54
# 元の文: ['you', 'take', 'more', 'calories', 'than', 'are', 'necessary', '.']
# 正解文: ['あなた', 'は', '必要', '以上', 'の', 'カロリー', 'を', 'と', 'っ', 'て', 'い', 'る', '。']
# 生成文: ['君', 'は', 'もっと', '注意', 'も', 'もっと', 'うま', 'く', 'い', 'っ', 'て', 'い', 'る', '。']
# bleu: 0.8091067115702212
#
# text_no: 55
# 元の文: ['along', 'with', 'his', 'children', 'he', 'fled', 'the', 'country', '.']
# 正解文: ['子供', 'たち', 'と', '一緒', 'に', '彼', 'は', 'その', '国', 'から', '逃げ出', 'し', 'た', '。']
# 生成文: ['彼', 'の', '子供', 'たち', 'は', '彼', 'の', 'ピアノ', 'の', '上', 'に', '見え', 'た', '。']
# bleu: 0.8091067115702212
#
# text_no: 56
# 元の文: ['these', 'books', 'are', 'my', 'books', '.']
# 正解文: ['これ', 'ら', 'の', '本', 'は', '私', 'の', '本', 'で', 'す', '。']
# 生成文: ['これ', 'ら', 'の', '本', 'は', '私', 'の', '本', 'で', 'す', '。']
# bleu: 0.9234732618882052
#
# text_no: 57
# 元の文: ['she', 'smiled', 'at', 'the', 'sight', 'of', 'her', 'mother', '.']
# 正解文: ['彼女', 'は', '母親', 'を', '見', 'て', 'にっこり', 'と', '笑', 'っ', 'た', '。']
# 生成文: ['彼女', 'は', '自分', 'の', '子供', 'を', '育て', 'られ', 'た', '。']
# bleu: 0.7952707287670506
#
# text_no: 58
# 元の文: ['is', 'this', 'a', 'radio', '?']
# 正解文: ['これ', 'は', 'ラジオ', 'で', 'す', 'か', '。']
# 生成文: ['この', 'ラジオ', 'は', 'ラジオ', 'で', 'す', 'か', '。']
# bleu: 0.8891397050194614
#
# text_no: 59
# 元の文: ['he', 'suggested', 'a', 'plan', 'similar', 'to', 'mine', '.']
# 正解文: ['彼', 'は', '私', 'の', 'と', 'よ', 'く', '似', 'た', '計画', 'を', '提案', 'し', 'た', '。']
# 生成文: ['彼', 'は', '私', 'の', '計画', 'を', '説明', 'し', 'た', '。']
# bleu: 0.9457416090031758
#
# text_no: 60
# 元の文: ['it', 'was', 'a', 'long', 'letter', '.']
# 正解文: ['それ', 'は', '長', 'い', '手紙', 'だっ', 'た', '。']
# 生成文: ['それ', 'は', '長', 'い', '時', 'だっ', 'た', '。']
# bleu: 0.8891397050194614
#
# text_no: 61
# 元の文: ['she', 'turned', 'pale', 'at', 'the', 'news', '.']
# 正解文: ['彼女', 'は', 'その', '知らせ', 'を', '聞', 'い', 'て', '青ざめ', 'た', '。']
# 生成文: ['彼女', 'は', 'その', '知らせ', 'を', '聞', 'い', 'て', '喜', 'ん', 'だ', '。']
# bleu: 0.8408964152537145
#
# text_no: 62
# 元の文: ['have', 'you', 'taken', 'your', 'medicine', 'yet', '?']
# 正解文: ['君', 'は', 'もう', '薬', 'を', '飲', 'み', 'ま', 'し', 'た', 'か', '。']
# 生成文: ['もう', '一杯', '薬', 'を', '持', 'っ', 'て', 'い', 'ま', 'す', 'か', '。']
# bleu: 0.8034284189446518
#
# text_no: 63
# 元の文: ['the', 'man', 'wanted', 'to', 'have', 'a', 'drink', '.']
# 正解文: ['その', '男', 'は', '一', '杯', '飲', 'み', 'た', 'かっ', 'た', 'の', 'で', 'す', '。']
# 生成文: ['その', '男', 'は', '飲', 'み', 'ながら', 'お', '願', 'い', 'し', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 64
# 元の文: ['she', 'is', 'not', 'as', 'tall', 'as', 'he', '.']
# 正解文: ['彼女', 'は', '彼', 'ほど', '背', 'が', '高', 'く', 'な', 'い', '。']
# 生成文: ['彼女', 'は', '彼', 'ほど', '背', 'が', '高', 'く', 'な', 'い', '。']
# bleu: 0.9510699415570292
#
# text_no: 65
# 元の文: ['there', 'are', 'as', 'good', 'fish', 'in', 'the', 'sea', 'now', 'as', 'ever', '.']
# 正解文: ['魚', 'は', '海', 'に', 'は', 'いくら', 'で', 'も', 'い', 'る', '。']
# 生成文: ['今', 'の', '海', 'に', 'は', '海', 'が', 'い', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 66
# 元の文: ['you', 'have', 'no', 'business', 'complaining', 'about', 'the', 'matter', '.']
# 正解文: ['君', 'は', 'その', '事', 'に', '不平', 'を', '言', 'う', 'こと', 'は', 'な', 'い', 'よ', '。']
# 生成文: ['その', '問題', 'に', 'つ', 'い', 'て', 'は', 'いけ', 'な', 'い', 'よ', '。']
# bleu: 0.8408964152537145
#
# text_no: 67
# 元の文: ['you', 'may', 'come', 'and', 'go', 'at', 'will', '.']
# 正解文: ['好き', 'な', 'よう', 'に', '行き', '来', 'し', 'て', 'い', 'い', 'で', 'す', 'よ', '。']
# 生成文: ['すぐ', 'に', '行', 'っ', 'て', '下さ', 'い', '。']
# bleu: 0.8891397050194614
#
# text_no: 68
# 元の文: ['let', "'s", 'think', 'out', 'another', 'way', '.']
# 正解文: ['別', 'の', '方法', 'を', '考え出', 'そ', 'う', '。']
# 生成文: ['ちょっと', '考え', 'て', 'み', 'よ', 'う', 'と', 'し', 'て', '。']
# bleu: 0.668740304976422
#
# text_no: 69
# 元の文: ['he', 'was', 'tired', 'from', 'his', 'long', 'walk', '.']
# 正解文: ['彼', 'は', '長', 'い', '散歩', 'で', '疲れ', 'た', '。']
# 生成文: ['彼', 'は', '長', 'い', '間', '歩', 'い', 'て', '疲れ', 'た', '。']
# bleu: 0.8931539818068694
#
# text_no: 70
# 元の文: ['i', 'meant', 'to', 'have', 'written', 'to', 'you', '.']
# 正解文: ['あなた', 'に', '手紙', 'を', '書', 'く', 'つもり', 'だっ', 'た', 'の', 'だ', 'が', '。']
# 生成文: ['私', 'は', 'あなた', 'に', 'あなた', 'を', '見', 'に', '行', 'っ', 'た', 'こと', 'を', '覚え', 'て', 'い', 'る', '。']
# bleu: 0.7259795291154771
#
# text_no: 71
# 元の文: ['my', 'mother', 'sent', 'me', 'a', 'birthday', 'present', '.']
# 正解文: ['母', 'が', '誕生', '日', 'の', 'プレゼント', 'を', '送', 'っ', 'て', 'くれ', 'た', '。']
# 生成文: ['母', 'は', '私', 'の', '誕生', '日', 'に', '招待', 'さ', 'せ', 'た', '。']
# bleu: 0.8034284189446518
#
# text_no: 72
# 元の文: ['there', 'is', 'little', 'wine', 'left', '.']
# 正解文: ['ワイン', 'は', 'ほとんど', '残', 'っ', 'て', 'い', 'な', 'い', '。']
# 生成文: ['もう', '少し', 'ミルク', 'が', 'あ', 'り', 'ま', 'す', '。']
# bleu: 0.5773502691896257
#
# text_no: 73
# 元の文: ['please', 'bring', 'me', 'some', 'glasses', '.']
# 正解文: ['コップ', 'を', 'いく', 'つ', 'か', '持', 'っ', 'て', 'き', 'て', '下さ', 'い', '。']
# 生成文: ['別', 'の', '写真', 'を', '見せ', 'て', 'くださ', 'い', '。']
# bleu: 0.816496580927726
#
# text_no: 74
# 元の文: ['the', 'old', 'man', 'left', 'a', 'large', 'fortune', 'to', 'his', 'wife', '.']
# 正解文: ['その', '老人', 'は', '妻', 'に', '莫大', 'な', '財産', 'を', '残', 'し', 'て', '死', 'ん', 'だ', '。']
# 生成文: ['老人', 'は', '老人', 'に', '大きな', 'を', '払', 'っ', 'た', '。']
# bleu: 0.7952707287670506
#
# text_no: 75
# 元の文: ['there', 'were', 'ten', 'eggs', 'in', 'all', '.']
# 正解文: ['卵', 'が', '全部', 'で', '１０', '個', 'あ', 'っ', 'た', '。']
# 生成文: ['１０', '月', '１０', '人', 'の', '間', 'に', 'い', 'た', '。']
# bleu: 0.668740304976422
#
# text_no: 76
# 元の文: ['i', "'ve", 'just', 'been', 'to', 'my', 'uncle', "'s", 'house', '.']
# 正解文: ['丁度', 'おじ', 'さん', 'の', '家', 'に', '行', 'っ', 'て', 'き', 'た', 'ところ', 'だ', '。']
# 生成文: ['私', 'は', '叔父', 'の', '家', 'に', 'い', 'た', '。']
# bleu: 0.8633400213704505
#
# text_no: 77
# 元の文: ['i', 'was', 'glad', 'to', 'hear', 'of', 'your', 'success', '.']
# 正解文: ['君', 'の', '成功', 'を', '聞', 'い', 'て', 'うれし', 'かっ', 'た', '。']
# 生成文: ['私', 'は', 'あなた', 'の', '成功', 'を', '聞', 'い', 'て', 'うれし', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 78
# 元の文: ['she', 'is', 'brushing', 'her', 'hair', '.']
# 正解文: ['彼女', 'は', '髪', 'に', 'ブラシ', 'を', 'かけ', 'て', 'い', 'る', '。']
# 生成文: ['彼女', 'は', '髪', 'を', '脱', 'い', 'て', 'い', 'る', '。']
# bleu: 0.9146912192286945
#
# text_no: 79
# 元の文: ['it', "'s", 'a', 'very', 'quiet', 'room', '.']
# 正解文: ['とても', '静か', 'な', '部屋', 'で', 'す', 'から', '。']
# 生成文: ['部屋', 'は', 'とても', '静か', 'に', 'し', 'て', 'い', 'る', '。']
# bleu: 0.668740304976422
#
# text_no: 80
# 元の文: ['this', 'book', 'will', 'do', '.']
# 正解文: ['この', '本', 'で', 'い', 'い', 'よ', '。']
# 生成文: ['この', '本', 'は', '君', 'の', 'だ', 'ろ', 'う', '。']
# bleu: 0.7598356856515925
#
# text_no: 81
# 元の文: ['the', 'work', 'should', 'let', 'up', 'by', 'a', 'week', 'from', 'today', '.']
# 正解文: ['仕事', 'は', '来週', 'の', '今日', 'まで', 'に', '一', '段落', 'する', 'はず', 'で', 'す', '。']
# 生成文: ['仕事', 'は', '来週', 'まで', 'は', '仕事', 'を', 'やめ', 'る', '。']
# bleu: 0.7400828044922853
#
# text_no: 82
# 元の文: ['you', 'had', 'better', 'do', 'it', 'at', 'once', '.']
# 正解文: ['君', 'は', 'それ', 'を', 'すぐ', 'し', 'た', 'ほう', 'が', 'よ', 'い', '。']
# 生成文: ['すぐ', 'に', 'それ', 'を', 'し', 'た', 'ほう', 'が', 'い', 'い', '。']
# bleu: 0.8593887047640296
#
# text_no: 83
# 元の文: ['don', "'t", 'turn', 'off', 'the', 'light', '.']
# 正解文: ['明かり', 'を', '消', 'さ', 'な', 'い', 'で', '下さ', 'い', '。']
# 生成文: ['明かり', 'を', '消', 'す', 'な', '。']
# bleu: 0.9036020036098448
#
# text_no: 84
# 元の文: ['was', 'it', 'necessary', 'that', 'my', 'uncle', 'be', 'informed', '?']
# 正解文: ['叔父', 'に', '知', 'ら', 'せ', 'る', 'こと', 'が', '必要', 'だっ', 'た', 'か', '。']
# 生成文: ['私', 'が', '自分', 'の', '弟', 'を', 'どう', 'し', 'て', 'もら', 'い', 'た', 'の', 'で', 'す', 'か', '。']
# bleu: 0.6964705665515708
#
# text_no: 85
# 元の文: ['my', 'father', 'died', 'at', 'the', 'age', 'of', 'forty-nine', '.']
# 正解文: ['父', 'は', '４９', '歳', 'で', 'な', 'く', 'な', 'っ', 'た', '。']
# 生成文: ['父', 'は', '年', 'を', '失', 'っ', 'た', '。']
# bleu: 0.8891397050194614
#
# text_no: 86
# 元の文: ['we', 'had', 'a', 'lovely', 'meal', '.']
# 正解文: ['私', 'たち', 'は', 'すばらし', 'い', '食事', 'を', 'し', 'た', '。']
# 生成文: ['私', 'たち', 'は', '食事', 'を', 'し', 'て', 'い', 'ま', 'し', 'た', '。']
# bleu: 0.8739351325046805
#
# text_no: 87
# 元の文: ['it', 'has', 'rained', 'for', 'three', 'days', 'on', 'end', '.']
# 正解文: ['３', '日間', '雨', 'が', '降', 'り', '続', 'い', 'て', 'い', 'る', '。']
# 生成文: ['３', '日間', '雨', 'が', '降', 'り', '続', 'い', 'た', '。']
# bleu: 0.9457416090031758
#
# text_no: 88
# 元の文: ['i', 'have', 'to', 'think', 'of', 'my', 'children', '.']
# 正解文: ['私', 'は', '子供', '達', 'の', 'こと', 'を', '考え', 'な', 'けれ', 'ば', 'な', 'ら', 'な', 'い', '。']
# 生成文: ['私', 'は', '子供', 'の', '世話', 'を', 'し', 'な', 'けれ', 'ば', 'な', 'ら', 'な', 'い', '。']
# bleu: 0.8801117367933934
#
# text_no: 89
# 元の文: ['do', 'you', 'have', 'earphones', '?']
# 正解文: ['イヤホン', 'を', '頼', 'ん', 'だ', 'はず', 'な', 'の', 'で', 'す', 'が', '。']
# 生成文: ['あなた', 'は', '好き', 'で', 'す', 'か', '。']
# bleu: 0.8694417438899827
#
# text_no: 90
# 元の文: ['illness', 'kept', 'me', 'from', 'going', 'there', '.']
# 正解文: ['病気', 'の', 'ため', 'に', '私', 'は', 'そこ', 'へ', '行け', 'な', 'かっ', 'た', '。']
# 生成文: ['病気', 'の', 'ため', '私', 'は', 'そこ', 'へ', '行', 'く', '途中', 'で', 'でき', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 91
# 元の文: ['he', 'gave', 'me', 'a', 'cold', '.']
# 正解文: ['彼', 'に', 'かぜ', 'を', 'うつ', 'さ', 'れ', 'た', '。']
# 生成文: ['彼', 'は', '私', 'に', '風邪', 'を', 'ひ', 'い', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 92
# 元の文: ['let', "'s", 'finish', 'it', 'right', 'away', '.']
# 正解文: ['それ', 'を', 'すぐ', '終え', 'ま', 'しょ', 'う', '。']
# 生成文: ['すぐ', 'に', 'それ', 'を', 'や', 'ら', 'せ', 'て', 'くださ', 'い', '。']
# bleu: 0.6529942057256104
#
# text_no: 93
# 元の文: ['my', 'family', 'are', 'all', 'well', '.']
# 正解文: ['家族', 'は', '全員', '元気', 'で', 'す', '。']
# 生成文: ['私', 'の', '家族', 'は', 'みな', '家族', 'で', 'す', '。']
# bleu: 0.816496580927726
#
# text_no: 94
# 元の文: ['i', 'hear', 'you', "'re", 'very', 'rich', '.']
# 正解文: ['あなた', 'は', '大', '金持ち', 'と', '評判', 'で', 'す', '。']
# 生成文: ['あなた', 'は', 'とても', '金持ち', 'だ', 'と', '思', 'い', 'ま', 'す', '。']
# bleu: 0.7765453555044466
#
# text_no: 95
# 元の文: ['there', 'is', 'one', 'big', 'difference', '.']
# 正解文: ['それ', 'は', '１', 'つ', 'の', '大きな', '違い', 'が', 'あ', 'る', 'から', 'だ', '。']
# 生成文: ['彼', 'に', 'は', '高', 'く', 'な', 'が', 'たくさん', 'あ', 'る', '。']
# bleu: 0.8593887047640296
#
# text_no: 96
# 元の文: ['we', 'had', 'better', 'go', 'home', 'rather', 'than', 'wait', 'here', '.']
# 正解文: ['ここ', 'で', '待', 'つ', 'より', '家', 'に', '帰', 'っ', 'た', '方', 'が', 'よ', 'かろ', 'う', '。']
# 生成文: ['私', 'たち', 'は', 'ここ', 'に', 'も', 'い', 'い', '家', 'を', '訪れ', 'る', '。']
# bleu: 0.6930977286178778
#
# text_no: 97
# 元の文: ['we', 'are', 'going', 'to', 'have', 'a', 'baby', '.']
# 正解文: ['もう', 'すぐ', '私', 'に', '赤ちゃん', 'が', '産まれ', 'る', 'ん', 'で', 'す', '。']
# 生成文: ['私', 'たち', 'は', '赤ん坊', 'を', '見', 'る', 'つもり', 'だ', '。']
# bleu: 0.7400828044922853
#
# text_no: 98
# 元の文: ['i', 'do', 'not', 'like', 'mathematics', 'very', 'much', '.']
# 正解文: ['数学', 'は', 'あまり', '好き', 'で', 'は', 'あ', 'り', 'ま', 'せ', 'ん', '。']
# 生成文: ['私', 'は', '数学', 'を', 'あまり', '好き', 'で', 'は', 'な', 'い', '。']
# bleu: 0.7226568811456053
#
# text_no: 99
# 元の文: ['this', 'is', 'the', 'reason', 'i', 'disagree', 'with', 'you', '.']
# 正解文: ['こう', 'い', 'う', 'わけ', 'で', '私', 'は', 'あなた', 'に', '反対', 'な', 'の', 'で', 'す', '。']
# 生成文: ['これ', 'と', '私', 'と', 'は', '君', 'が', '同意', 'し', 'ま', 'す', '。']
# bleu: 0.7598356856515925
#
# text_no: 100
# 元の文: ['take', 'it', 'easy', '.', 'things', 'are', 'looking', 'up', '.']
# 正解文: ['心配', 'する', 'な', '。', '事態', 'は', '好転', 'し', 'て', 'い', 'る', '。']
# 生成文: ['そんな', '水', 'を', '見', 'て', 'み', 'て', 'み', 'な', 'さ', 'い', '。']
# bleu: 0.7598356856515925
#
# text_no: 101
# 元の文: ['i', 'haven', "'t", 'heard', 'of', 'him', 'since', 'then', '.']
# 正解文: ['私', 'は', 'それ', '以来', '彼', 'の', '消息', 'は', '聞', 'い', 'て', 'い', 'な', 'い', '。']
# 生成文: ['彼', 'から', 'の', 'ところ', 'から', '私', 'は', 'それ', 'が', '聞こえ', 'な', 'い', '。']
# bleu: 0.8566209113168688
#
# text_no: 102
# 元の文: ['the', 'teacher', 'made', 'him', 'stay', 'after', 'school', '.']
# 正解文: ['先生', 'は', '彼', 'を', '放課', '後', '残', 'ら', 'せ', 'た', '。']
# 生成文: ['先生', 'は', '彼', 'ら', 'に', '野球', 'を', 'し', 'た', '。']
# bleu: 0.8801117367933934
#
# text_no: 103
# 元の文: ['when', 'did', 'you', 'finish', 'the', 'work', '?']
# 正解文: ['あなた', 'は', 'いつ', 'その', '作品', 'を', '仕上げ', 'ま', 'し', 'た', 'か', '。']
# 生成文: ['いつ', 'その', '仕事', 'を', '終え', 'ま', 'し', 'た', 'か', '。']
# bleu: 0.8801117367933934
#
# text_no: 104
# 元の文: ['you', 'may', 'as', 'well', 'say', 'so', '.']
# 正解文: ['君', 'は', 'そう', '言', 'う', 'ほう', 'が', 'よ', 'い', '。']
# 生成文: ['そう', 'い', 'う', 'と', '言', 'う', 'の', 'は', '、', 'もっとも', 'だ', '。']
# bleu: 0.8034284189446518
#
# text_no: 105
# 元の文: ['his', 'car', 'fell', 'into', 'the', 'lake', '.']
# 正解文: ['彼', 'の', '車', 'は', '湖', 'の', '中', 'に', '落ち', 'た', '。']
# 生成文: ['彼', 'の', '車', 'は', '湖', 'に', '乗', 'っ', 'て', 'き', 'た', '。']
# bleu: 0.9036020036098448
#
# text_no: 106
# 元の文: ['she', 'was', 'happy', 'for', 'some', 'time', '.']
# 正解文: ['彼女', 'は', 'しばらく', 'の', '間', '幸福', 'だっ', 'た', '。']
# 生成文: ['彼女', 'は', '楽し', 'い', '過ご', 'を', 'し', 'て', 'い', 'た', '。']
# bleu: 0.7765453555044466
#
# text_no: 107
# 元の文: ['she', 'studies', 'hard', '.']
# 正解文: ['彼女', 'は', '熱心', 'に', '勉強', 'する', '。']
# 生成文: ['彼女', 'は', '一生', '懸命', '勉強', 'し', 'ま', 'す', '。']
# bleu: 0.7598356856515925
#
# text_no: 108
# 元の文: ['those', 'students', 'work', 'hard', ',', 'don', "'t", 'they', '?']
# 正解文: ['あの', '学生', 'たち', 'は', 'よく', '勉強', 'する', 'ね', '？']
# 生成文: ['生徒', 'たち', 'は', '英語', 'を', '学', 'ぶ', '必要', 'が', 'あ', 'る', 'の', 'で', 'す', 'か', '。']
# bleu: 0.7825422900366437
#
# text_no: 109
# 元の文: ['my', 'house', 'is', 'a', 'little', 'way', 'from', 'the', 'street', '.']
# 正解文: ['私', 'の', '家', 'は', 'その', '通り', 'から', '少し', '入', 'っ', 'た', 'ところ', 'だ', '。']
# 生成文: ['私', 'の', '家', 'は', '道路', 'の', 'そば', 'に', 'は', '少し', 'も', 'あ', 'り', 'ま', 'せ', 'ん', '。']
# bleu: 0.7707713836060629
#
# text_no: 110
# 元の文: ['i', 'will', 'keep', 'your', 'advice', 'in', 'mind', '.']
# 正解文: ['私', 'は', 'あなた', 'の', 'アドバイス', 'を', '心', 'に', '留め', 'て', 'お', 'き', 'た', 'い', '。']
# 生成文: ['私', 'は', '自分', 'の', 'ため', 'に', '心配', 'する', 'よう', 'に', 'し', 'なさ', 'い', '。']
# bleu: 0.8091067115702212
#
# text_no: 111
# 元の文: ['it', 'is', 'impossible', 'for', 'him', 'to', 'become', 'a', 'doctor', '.']
# 正解文: ['彼', 'が', '医者', 'に', 'な', 'る', 'の', 'は', '不', '可能', 'だ', '。']
# 生成文: ['彼', 'が', '医者', 'に', 'な', 'る', 'の', 'は', '不', '可能', 'だ', '。']
# bleu: 0.9554427922043668
#
# text_no: 112
# 元の文: ['you', 'can', 'use', 'my', 'car', 'today', '.']
# 正解文: ['今日', '私', 'の', '車', 'を', '使', 'っ', 'て', 'い', 'い', 'よ', '。']
# 生成文: ['今日', 'は', '私', 'の', '車', 'を', '使', 'っ', 'て', 'も', 'い', 'い', '。']
# bleu: 0.912167909070388
#
# text_no: 113
# 元の文: ['the', 'boy', 'was', 'laughed', 'at', 'by', 'everybody', '.']
# 正解文: ['その', '男の子', 'は', 'みんな', 'から', '笑', 'わ', 'れ', 'ま', 'し', 'た', '。']
# 生成文: ['その', '少年', 'は', 'みんな', 'に', '笑', 'わ', 'れ', 'た', '。']
# bleu: 0.8801117367933934
#
# text_no: 114
# 元の文: ['he', 'can', 'also', 'speak', 'french', '.']
# 正解文: ['彼', 'は', 'フランス', '語', 'も', '話せ', 'る', '。']
# 生成文: ['彼', 'は', 'フランス', '語', 'も', '話せ', 'る', '。']
# bleu: 0.9306048591020996
#
# text_no: 115
# 元の文: ['i', "'m", 'too', 'busy', 'to', 'help', 'her', '.']
# 正解文: ['私', 'は', 'とても', '忙し', 'い', 'の', 'で', '彼女', 'を', '手伝え', 'ま', 'せ', 'ん', '。']
# 生成文: ['私', 'は', '彼女', 'に', '似', 'て', 'い', 'る', 'の', 'が', '好き', 'で', 'な', 'い', '。']
# bleu: 0.8265168183793802
#
# text_no: 116
# 元の文: ['she', 'is', 'getting', 'better', 'day', 'by', 'day', '.']
# 正解文: ['彼女', 'は', '日', 'ごと', 'に', '快方', 'に', '向か', 'っ', 'て', 'い', 'ま', 'す', '。']
# 生成文: ['彼女', 'は', '毎日', '日', 'に', '出かけ', 'る', '。']
# bleu: 0.8408964152537145
#
# text_no: 117
# 元の文: ['he', 'comes', 'to', 'tokyo', 'once', 'a', 'year', '.']
# 正解文: ['彼', 'は', '１', '年', 'に', '１', '度', '上京', 'する', '。']
# 生成文: ['彼', 'は', '一', '日', '東京', 'に', '行', 'き', 'ま', 'す', '。']
# bleu: 0.8210967436686386
#
# text_no: 118
# 元の文: ['don', "'t", 'fail', 'to', 'call', 'me', 'back', '.']
# 正解文: ['必ず', '私', 'に', '電話', 'を', 'かけ', '直', 'し', 'て', '下さ', 'い', '。']
# 生成文: ['電話', 'を', 'かけ', 'て', 'くれ', 'な', 'い', 'よう', 'に', 'し', 'て', 'くださ', 'い', '。']
# bleu: 0.8091067115702212
#
# text_no: 119
# 元の文: ['it', "'s", 'no', 'trouble', 'at', 'all', '.']
# 正解文: ['全然', 'かま', 'い', 'ま', 'せ', 'ん', 'わ', '。']
# 生成文: ['それ', 'は', '誰', 'も', 'に', 'し', 'な', 'い', '。']
# bleu: 0.6865890479690392
#
# text_no: 120
# 元の文: ['he', 'came', 'down', 'the', 'road', '.']
# 正解文: ['彼', 'は', 'その', '道', 'を', 'や', 'っ', 'て', 'き', 'た', '。']
# 生成文: ['彼', 'は', '道', 'を', '道', 'に', '入', 'っ', 'て', 'き', 'た', '。']
# bleu: 0.9306048591020996
#
# text_no: 121
# 元の文: ['he', 'liked', 'history', 'among', 'others', '.']
# 正解文: ['彼', 'は', '中', 'で', 'も', '歴史', 'が', '好き', 'だっ', 'た', '。']
# 生成文: ['彼', 'は', '彼', 'の', '援助', 'を', '愛', 'し', 'て', 'しま', 'っ', 'た', '。']
# bleu: 0.7875110621102679
#
# text_no: 122
# 元の文: ['he', 'may', 'be', 'in', 'paris', 'now', 'for', 'anything', 'i', 'know', '.']
# 正解文: ['とにかく', '彼', 'は', '今', 'パリ', 'に', 'い', 'る', 'で', 'しょ', 'う', '。']
# 生成文: ['彼', 'は', '今', 'の', 'ところ', '本当', 'に', 'よく', '知', 'ら', 'れ', 'て', 'い', 'る', '。']
# bleu: 0.8265168183793802
#
# text_no: 123
# 元の文: ['we', 'have', 'been', 'here', 'long', 'enough', '.']
# 正解文: ['私', 'たち', 'は', 'もう', 'ずいぶん', '長', 'く', 'ここ', 'に', 'い', 'ま', 'す', '。']
# 生成文: ['ここ', 'に', 'は', '長', 'い', '間', 'たくさん', 'あ', 'る', '。']
# bleu: 0.8408964152537145
#
# text_no: 124
# 元の文: ['she', 'was', 'born', 'in', 'a', 'small', 'village', '.']
# 正解文: ['彼女', 'は', '小さな', '村', 'で', '生まれ', 'ま', 'し', 'た', '。']
# 生成文: ['彼女', 'は', '小さな', '村', 'に', '住', 'ん', 'で', 'い', 'た', '。']
# bleu: 0.8210967436686386
#
# text_no: 125
# 元の文: ['naomi', 'has', 'just', 'finished', 'her', 'work', '.']
# 正解文: ['直美', 'は', 'ちょうど', '仕事', 'を', 'し', '終え', 'た', 'ところ', 'だ', '。']
# 生成文: ['ちょうど', '彼女', 'から', '仕事', 'を', '終え', 'た', 'ところ', 'だ', '。']
# bleu: 0.7952707287670506
#
# text_no: 126
# 元の文: ['i', "'m", 'sorry', 'to', 'trouble', 'you', 'so', 'much', '.']
# 正解文: ['こんな', 'に', 'ご', '面倒', 'を', 'かけ', 'て', 'す', 'み', 'ま', 'せ', 'ん', '。']
# 生成文: ['こんな', 'に', 'お', '目', 'に', 'かか', 'り', 'た', 'く', 'な', 'い', 'ん', 'で', 'す', 'よ', '。']
# bleu: 0.7476743906106103
#
# text_no: 127
# 元の文: ['i', "'d", 'like', 'you', 'to', 'cut', 'my', 'hair', '.']
# 正解文: ['髪', 'を', '切', 'っ', 'て', 'もら', 'い', 'た', 'い', 'ん', 'で', 'す', 'が', '。']
# 生成文: ['髪', 'を', '切', 'っ', 'て', 'ほし', 'い', 'の', 'で', 'す', 'が', '。']
# bleu: 0.9554427922043668
#
# text_no: 128
# 元の文: ['it', "'s", 'difficult', 'to', 'feel', 'at', 'home', 'in', 'a', 'foreign', 'language', '.']
# 正解文: ['外国', '語', 'に', '十分', '慣れ', 'る', 'こと', 'は', '困難', 'だ', '。']
# 生成文: ['外国', 'で', 'は', '外国', '語', 'を', '学', 'ぶ', 'こと', 'に', 'は', 'な', 'い', '。']
# bleu: 0.7311104457090247
#
# text_no: 129
# 元の文: ['is', 'it', 'baked', '?']
# 正解文: ['それ', 'は', '焼', 'い', 'て', 'あ', 'る', 'の', 'で', 'す', 'か', '。']
# 生成文: ['それ', 'は', '何', 'で', 'す', 'か', '。']
# bleu: 0.9193227152249185
#
# text_no: 130
# 元の文: ['he', 'is', 'well', 'spoken', 'of', 'by', 'everybody', '.']
# 正解文: ['彼', 'は', 'みんな', 'に', 'ほめ', 'られ', 'る', '。']
# 生成文: ['彼', 'は', '誰', 'に', 'も', 'よく', '他人', 'の', '悪口', 'を', '言', 'う', '。']
# bleu: 0.7447819789879647
#
# text_no: 131
# 元の文: ['how', 'much', 'should', 'i', 'pay', 'today', '?']
# 正解文: ['今日', 'は', 'お', 'いくら', 'で', 'す', 'か', '。']
# 生成文: ['今日', 'は', '何', 'と', 'お', '手伝い', 'し', 'ま', 'す', 'か', '。']
# bleu: 0.8210967436686386
#
# text_no: 132
# 元の文: ['please', 'call', 'me', 'at', 'this', 'number', '.']
# 正解文: ['この', '番号', 'に', '電話', 'を', '下さ', 'い', '。']
# 生成文: ['この', '手紙', 'を', '書', 'い', 'て', 'くださ', 'い', '。']
# bleu: 0.7598356856515925
#
# text_no: 133
# 元の文: ['my', 'dog', 'goes', 'everywhere', 'with', 'me', '.']
# 正解文: ['私', 'の', '犬', 'は', '私', 'に', 'どこ', 'へ', 'で', 'も', 'つ', 'い', 'て', 'くる', '。']
# 生成文: ['私', 'の', '犬', 'は', '私', 'の', '手', 'に', '負え', 'な', 'い', '。']
# bleu: 0.8739351325046805
#
# text_no: 134
# 元の文: ['her', 'composition', 'was', 'free', 'from', 'mistakes', '.']
# 正解文: ['彼女', 'の', '作文', 'に', 'は', '誤り', 'が', 'な', 'かっ', 'た', '。']
# 生成文: ['彼女', 'の', '失敗', 'は', 'ほとんど', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 135
# 元の文: ['she', 'seems', 'to', 'have', 'been', 'in', 'poor', 'health', 'in', 'her', 'childhood', '.']
# 正解文: ['彼女', 'は', '子供', 'の', 'ころ', '病弱', 'だっ', 'た', 'ら', 'しい', '。']
# 生成文: ['彼女', 'は', '子供', 'の', 'ころ', '信', 'じ', 'て', 'い', 'た', 'よう', 'に', '見え', 'る', '。']
# bleu: 0.7598356856515925
#
# text_no: 136
# 元の文: ['i', 'have', 'nothing', 'to', 'tell', 'you', 'for', 'the', 'moment', '.']
# 正解文: ['さしあたり', '君', 'に', '言', 'う', '事', 'は', '無', 'い', '。']
# 生成文: ['君', 'に', 'は', '何', 'も', '見え', 'な', 'い', '。']
# bleu: 0.8633400213704505
#
# text_no: 137
# 元の文: ['she', 'is', 'not', 'anything', 'like', 'her', 'mother', '.']
# 正解文: ['彼女', 'は', '母親', 'と', 'まるで', '違', 'う', '。']
# 生成文: ['彼女', 'は', '母親', 'に', 'は', '似', 'て', 'い', 'な', 'い', '。']
# bleu: 0.6529942057256104
#
# text_no: 138
# 元の文: ['this', 'is', 'the', 'village', 'where', 'he', 'was', 'born', '.']
# 正解文: ['これ', 'は', '彼', 'が', '生まれ', 'た', '村', 'だ', '。']
# 生成文: ['ここ', 'は', '彼', 'が', '生まれ', 'た', 'の', 'で', 'す', '。']
# bleu: 0.8408964152537145
#
# text_no: 139
# 元の文: ['he', 'is', 'a', 'good', 'fellow', '.']
# 正解文: ['彼', 'は', 'い', 'い', 'やつ', 'だ', '。']
# 生成文: ['彼', 'は', 'よ', 'い', 'よろし', 'い', '。']
# bleu: 0.8694417438899827
#
# text_no: 140
# 元の文: ['the', 'accident', 'was', 'due', 'to', 'his', 'carelessness', '.']
# 正解文: ['事故', 'は', '彼', 'の', '不', '注意', 'が', '原因', 'だっ', 'た', '。']
# 生成文: ['その', '事故', 'は', '彼', 'の', '不', '注意', 'に', 'よ', 'く', 'な', 'っ', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 141
# 元の文: ['i', "'ll", 'see', 'you', 'a', 'week', 'from', 'today', '.']
# 正解文: ['来週', 'の', '今日', 'お', '会', 'い', 'し', 'ま', 'す', '。']
# 生成文: ['今日', 'は', '一', '週間', 'お', '会', 'い', 'ま', 'す', '。']
# bleu: 0.8801117367933934
#
# text_no: 142
# 元の文: ['where', 'are', 'you', 'going', '?']
# 正解文: ['どちら', 'が', '先', 'に', '行', 'く', 'の', 'で', 'す', 'か', '。']
# 生成文: ['どこ', 'へ', '行', 'き', 'ま', 'す', 'か', '。']
# bleu: 0.8408964152537145
#
# text_no: 143
# 元の文: ['it', "'s", 'stormy', '.']
# 正解文: ['天気', 'は', '荒れ', 'て', 'い', 'ま', 'す', '。']
# 生成文: ['それ', 'は', '、', 'それ', 'で', 'す', '。']
# bleu: 0.8091067115702212
#
# text_no: 144
# 元の文: ['i', 'saw', 'the', 'film', 'and', 'found', 'it', 'interesting', '.']
# 正解文: ['その', '映画', 'を', '見', 'た', 'けれど', '面白', 'かっ', 'た', 'よ', '。']
# 生成文: ['その', '映画', 'を', '見', 'る', 'と', '面白', 'い', '。']
# bleu: 0.7598356856515925
#
# text_no: 145
# 元の文: ['she', 'looks', 'better', 'in', 'japanese', 'clothes', '.']
# 正解文: ['彼女', 'は', '和服', 'の', '方', 'が', '良', 'く', '似合', 'う', '。']
# 生成文: ['彼女', 'は', '日本', 'の', '服', 'を', '着', 'て', 'い', 'る', 'よう', 'だ', '。']
# bleu: 0.7447819789879647
#
# text_no: 146
# 元の文: ['i', 'have', 'already', 'changed', 'my', 'clothes', '.']
# 正解文: ['私', 'は', 'もう', '着替え', 'ま', 'し', 'た', '。']
# 生成文: ['私', 'は', '手', 'に', '関', 'し', 'て', 'もら', 'い', 'た', '。']
# bleu: 0.8210967436686386
#
# text_no: 147
# 元の文: ['we', 'call', 'the', 'mountain', 'tsurugidake', '.']
# 正解文: ['その', '山', 'を', '私', 'たち', 'は', '剣岳', 'と', '呼', 'ぶ', '。']
# 生成文: ['私', 'たち', 'は', 'その', '山', 'を', '渡', 'る', 'の', 'を', 'やめ', 'る', '。']
# bleu: 0.8242367502646054
#
# text_no: 148
# 元の文: ['you', 'aren', "'t", 'yourself', 'today', '.']
# 正解文: ['今日', 'は', 'いつ', 'も', 'の', '君', 'らし', 'く', 'な', 'い', '。']
# 生成文: ['今日', 'は', 'あなた', 'に', 'は', '若', 'く', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 149
# 元の文: ['your', 'sister', 'is', 'the', 'most', 'diligent', 'of', 'all', 'my', 'friends', '.']
# 正解文: ['あなた', 'の', '妹', 'は', '友達', 'の', '中', 'で', '一番', '勤勉', 'で', 'す', '。']
# 生成文: ['あなた', 'の', '妹', 'は', '私', 'の', '妹', 'の', '年', 'の', '中', 'で', 'す', '。']
# bleu: 0.8408964152537145
#
# text_no: 150
# 元の文: ['no', 'river', 'in', 'the', 'world', 'is', 'longer', 'than', 'the', 'nile', '.']
# 正解文: ['ナイル', '川', 'より', '長', 'い', '川', 'は', '世界', '中', 'に', 'な', 'い', '。']
# 生成文: ['川', 'で', 'は', '寒', 'く', 'は', '生き', 'られ', 'な', 'い', '。']
# bleu: 0.8210967436686386
#
# text_no: 151
# 元の文: ['she', 'was', 'afraid', 'of', 'the', 'dog', '.']
# 正解文: ['彼女', 'は', 'その', '犬', 'を', '恐れ', 'た', '。']
# 生成文: ['彼女', 'は', '犬', 'を', '恐れ', 'て', 'い', 'た', '。']
# bleu: 0.8633400213704505
#
# text_no: 152
# 元の文: ['it', 'is', 'wrong', 'to', 'tell', 'lies', '.']
# 正解文: ['嘘', 'を', 'つ', 'く', 'こと', 'は', '悪', 'い', '。']
# 生成文: ['そんな', 'こと', 'を', '言', 'う', 'と', 'は', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 153
# 元の文: ['i', 'have', 'a', 'poor', 'appetite', 'these', 'days', '.']
# 正解文: ['私', 'は', '最近', '食欲', 'が', '無', 'い', '。']
# 生成文: ['私', 'は', '去年', 'の', '高', 'い', 'ビル', 'を', '持', 'っ', 'て', 'い', 'ま', 'せ', 'ん', '。']
# bleu: 0.7071067811865476
#
# text_no: 154
# 元の文: ['be', 'sure', 'to', 'put', 'out', 'the', 'fire', 'before', 'you', 'leave', '.']
# 正解文: ['あなた', 'は', '離れ', 'る', '前', 'に', '必ず', '火', 'を', '消', 'し', 'なさ', 'い', '。']
# 生成文: ['出かけ', 'る', '前', 'に', '必ず', '火', 'を', '消', 'し', 'なさ', 'い', '。']
# bleu: 0.9306048591020996
#
# text_no: 155
# 元の文: ['the', 'river', 'is', 'deep', 'here', '.']
# 正解文: ['川', 'は', 'この', '辺', 'が', '深', 'い', '。']
# 生成文: ['その', '川', 'は', '今', 'の', '間', 'で', 'す', '。']
# bleu: 0.816496580927726
#
# text_no: 156
# 元の文: ['so', ',', 'when', 'are', 'you', 'going', 'to', 'break', 'down', 'and', 'buy', 'a', 'house', '?']
# 正解文: ['いつ', 'に', 'な', 'っ', 'たら', '家', 'を', '買', 'う', 'つもり', 'な', 'の', '？']
# 生成文: ['なぜ', '、', '店', 'に', 'る', 'の', 'を', '買', 'う', 'の', 'で', 'す', 'か', '。']
# bleu: 0.7730551756939454
#
# text_no: 157
# 元の文: ['it', 'seemed', 'that', 'he', 'was', 'sick', '.']
# 正解文: ['彼', 'は', '病気', 'の', 'よう', 'だっ', 'た', '。']
# 生成文: ['彼', 'は', '病気', 'だっ', 'た', 'ら', 'しい', '。']
# bleu: 0.8408964152537145
#
# text_no: 158
# 元の文: ['have', 'you', 'called', 'her', 'yet', '?']
# 正解文: ['彼女', 'に', '電話', 'し', 'ま', 'し', 'た', 'か', '。']
# 生成文: ['もう', '彼女', 'に', '電話', 'し', 'ま', 'し', 'た', 'か', '。']
# bleu: 0.8801117367933934
#
# text_no: 159
# 元の文: ['i', 'wonder', 'if', 'he', "'ll", 'come', 'tomorrow', '.']
# 正解文: ['彼', 'は', 'あした', '来る', 'か', 'な', '。']
# 生成文: ['彼', 'は', '明日', '来る', 'だ', 'ろ', 'う', 'か', '。']
# bleu: 0.816496580927726
#
# text_no: 160
# 元の文: ['i', "'ll", 'call', 'him', 'back', 'later', '.']
# 正解文: ['あと', 'で', 'また', '、', '彼', 'に', '電話', 'し', 'ま', 'す', '。']
# 生成文: ['後', 'で', '彼', 'に', '電話', 'し', 'ま', 'す', '。']
# bleu: 0.9391044157537525
#
# text_no: 161
# 元の文: ['how', 'did', 'the', 'party', 'go', '?']
# 正解文: ['パーティ', 'の', '進', 'み', '具合', 'は', '。']
# 生成文: ['パーティー', 'は', 'どう', 'で', 'し', 'た', 'か', '。']
# bleu: 0.7071067811865476
#
# text_no: 162
# 元の文: ['i', "'m", 'dying', 'for', 'a', 'cup', 'of', 'coffee', '.']
# 正解文: ['コーヒー', 'が', '飲', 'み', 'た', 'く', 'て', '仕方', 'が', 'な', 'い', '。']
# 生成文: ['私', 'は', 'コーヒー', 'を', '飲', 'み', 'ま', 'す', '。']
# bleu: 0.7598356856515925
#
# text_no: 163
# 元の文: ['write', 'me', 'sometime', ',', 'ok', '?']
# 正解文: ['手紙', '書', 'い', 'て', 'ね', '。']
# 生成文: ['いつ', 'か', '書', 'い', 'て', 'くださ', 'い', 'ま', 'す', 'か', '。']
# bleu: 0.7765453555044466
#
# text_no: 164
# 元の文: ['he', 'lost', 'his', 'eyesight', 'when', 'he', 'was', 'still', 'a', 'child', '.']
# 正解文: ['彼', 'は', '子供', 'の', 'ころ', '視力', 'を', '失', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '自分', 'の', '病気', 'で', 'あ', 'る', 'こと', 'が', 'でき', 'た', '。']
# bleu: 0.7875110621102679
#
# text_no: 165
# 元の文: ['we', 'have', 'three', 'meals', 'a', 'day', '.']
# 正解文: ['私', 'たち', 'は', '、', '一', '日', 'に', '三', '食', 'と', 'り', 'ま', 'す', '。']
# 生成文: ['私', 'たち', 'は', '１', '日', '３', '回', '食事', 'を', 'し', 'ま', 'す', '。']
# bleu: 0.8242367502646054
#
# text_no: 166
# 元の文: ['what', 'did', 'you', 'buy', 'it', 'for', '?']
# 正解文: ['何', 'の', 'ため', 'に', 'それ', 'を', '買', 'っ', 'た', 'の', 'か', '。']
# 生成文: ['それ', 'を', '何', 'と', '買', 'っ', 'た', 'の', 'で', 'す', 'か', '。']
# bleu: 0.9036020036098448
#
# text_no: 167
# 元の文: ['you', 'must', 'study', 'your', 'whole', 'life', '.']
# 正解文: ['あなた', 'は', '、', '一生', '勉強', 'し', 'な', 'けれ', 'ば', 'な', 'ら', 'な', 'い', '。']
# 生成文: ['あなた', 'は', '一生', '懸命', '勉強', 'し', '続け', 'た', '。']
# bleu: 0.816496580927726
#
# text_no: 168
# 元の文: ['he', 'heard', 'the', 'dog', 'barking', '.']
# 正解文: ['彼', 'は', '犬', 'が', 'ほえ', 'て', 'い', 'る', 'の', 'を', '聞', 'い', 'た', '。']
# 生成文: ['彼', 'は', 'その', '犬', 'の', '世話', 'を', 'し', 'た', '。']
# bleu: 0.9146912192286945
#
# text_no: 169
# 元の文: ['that', 'pretty', 'girl', 'is', 'my', 'sister', '.']
# 正解文: ['あの', 'かわい', 'い', '少女', 'は', '私', 'の', '妹', 'で', 'す', '。']
# 生成文: ['あの', '女の子', 'は', '私', 'の', '妹', 'と', '違', 'う', '。']
# bleu: 0.8408964152537145
#
# text_no: 170
# 元の文: ['the', 'property', 'passed', 'from', 'father', 'to', 'son', '.']
# 正解文: ['財産', 'は', '父', 'から', '息子', 'へ', 'と', '譲', 'ら', 'れ', 'た', '。']
# 生成文: ['その', '会社', 'は', '彼', 'の', '息子', 'に', '腹', 'を', '立て', 'た', '。']
# bleu: 0.7071067811865476
#
# text_no: 171
# 元の文: ['you', 'cannot', 'solve', 'this', 'problem', 'in', 'an', 'ordinary', 'way', '.']
# 正解文: ['この', '問題', 'は', 'あたりまえ', 'の', 'や', 'り', '方', 'で', 'は', '解決', 'し', 'な', 'い', '。']
# 生成文: ['この', '問題', 'は', '解', 'く', 'べ', 'き', 'で', 'は', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 172
# 元の文: ['you', 'are', 'new', 'students', '.']
# 正解文: ['君', '達', 'は', '新入', '生', 'で', 'す', '。']
# 生成文: ['あなた', 'は', '高校', '生', 'で', 'す', '。']
# bleu: 0.9193227152249185
#
# text_no: 173
# 元の文: ['the', 'picture', 'hangs', 'over', 'the', 'table', '.']
# 正解文: ['絵', 'が', 'テーブル', 'の', '上', 'に', 'かか', 'っ', 'て', 'い', 'る', '。']
# 生成文: ['その', '絵', 'は', 'どこ', 'か', '絵', 'を', '見', 'て', 'い', 'る', '。']
# bleu: 0.8408964152537145
#
# text_no: 174
# 元の文: ['she', 'asked', 'me', 'where', 'to', 'go', '.']
# 正解文: ['彼女', 'は', '私', 'に', 'どこ', 'へ', '行', 'っ', 'たら', 'よ', 'い', 'か', '聞', 'い', 'た', '。']
# 生成文: ['彼女', 'は', '私', 'に', 'どこ', 'へ', '行', 'か', 'せ', 'た', 'か', 'を', '説明', 'し', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 175
# 元の文: ['she', 'is', 'a', 'friend', 'of', 'the', 'poor', '.']
# 正解文: ['彼女', 'は', '貧し', 'い', '人', '達', 'の', '味方', 'で', 'す', '。']
# 生成文: ['彼女', 'は', '音楽', 'が', '大好き', 'で', 'あ', 'る', '。']
# bleu: 0.7598356856515925
#
# text_no: 176
# 元の文: ['i', 'saw', 'it', 'with', 'my', 'own', 'eyes', '.']
# 正解文: ['私', 'は', '自分', 'の', '目', 'で', 'それ', 'を', '見', 'た', 'の', 'で', 'す', '。']
# 生成文: ['私', 'は', '自分', 'で', 'それ', 'を', '見', 'た', '。']
# bleu: 0.9391044157537525
#
# text_no: 177
# 元の文: ['i', "'ve", 'been', 'looking', 'for', 'you', '.']
# 正解文: ['僕', 'は', '君', 'を', '探', 'し', 'て', 'い', 'た', 'の', 'だ', '。']
# 生成文: ['あなた', 'を', '探', 'し', 'て', 'い', 'ま', 'す', '。']
# bleu: 0.9036020036098448
#
# text_no: 178
# 元の文: ['the', 'old', 'man', 'said', 'something', '.']
# 正解文: ['その', '老人', 'は', '何', 'か', '言', 'い', 'ま', 'し', 'た', '。']
# 生成文: ['その', '老人', 'は', '君', 'の', '考え', 'を', '取', 'っ', 'た', '。']
# bleu: 0.7765453555044466
#
# text_no: 179
# 元の文: ['i', 'was', 'asked', 'to', 'open', 'the', 'gate', '.']
# 正解文: ['私', 'は', '門', 'を', '開け', 'る', 'よう', 'に', '頼', 'ま', 'れ', 'た', '。']
# 生成文: ['私', 'は', 'その', '要求', 'を', '開', 'く', 'の', 'を', '聞', 'い', 'た', '。']
# bleu: 0.8242367502646054
#
# text_no: 180
# 元の文: ['i', "'m", 'willing', 'to', 'help', 'him', '.']
# 正解文: ['喜', 'ん', 'で', '彼', 'の', '助け', 'に', 'な', 'り', 'ま', 'す', '。']
# 生成文: ['私', 'は', '彼', 'を', '助け', 'る', 'ため', 'に', '頼', 'る', '。']
# bleu: 0.7226568811456053
#
# text_no: 181
# 元の文: ['yumi', 'went', 'there', 'by', 'herself', '.']
# 正解文: ['由美', 'は', '一人', 'で', 'そこ', 'へ', '行', 'っ', 'た', '。']
# 生成文: ['ついに', 'そこ', 'へ', '行', 'っ', 'た', '。']
# bleu: 0.9193227152249185
#
# text_no: 182
# 元の文: ['his', 'face', 'says', 'that', 'he', 'lost', '.']
# 正解文: ['彼', 'が', '負け', 'た', 'こと', 'は', '顔つき', 'で', 'わか', 'る', '。']
# 生成文: ['彼', 'の', '顔', 'は', '怒', 'っ', 'て', 'い', 'る', 'よう', 'に', '見え', 'る', '。']
# bleu: 0.7730551756939454
#
# text_no: 183
# 元の文: ['no', 'other', 'boy', 'in', 'his', 'class', 'is', 'as', 'bright', 'as', 'he', '.']
# 正解文: ['クラス', 'で', '彼', 'ほど', '頭', 'の', 'い', 'い', '少年', 'は', 'い', 'な', 'い', '。']
# 生成文: ['彼', 'の', '家', 'の', '中', 'で', 'は', '彼', 'の', '家', 'の', 'どちら', 'も', 'い', 'い', 'な', 'い', '。']
# bleu: 0.7896895367562644
#
# text_no: 184
# 元の文: ['by', 'the', 'way', ',', 'what', 'do', 'you', 'do', '?']
# 正解文: ['ところ', 'で', '、', 'あなた', 'の', '仕事', 'は', '何', 'で', 'す', 'か', '。']
# 生成文: ['す', 'み', 'ま', 'せ', 'ん', '、', '何', '時', 'に', 'し', 'て', '起こ', 'り', 'ま', 'す', 'か', '。']
# bleu: 0.7364279629037999
#
# text_no: 185
# 元の文: ['my', 'dream', 'is', 'to', 'become', 'a', 'teacher', '.']
# 正解文: ['私', 'の', '夢', 'は', '先生', 'に', 'な', 'る', 'こと', 'で', 'す', '。']
# 生成文: ['私', 'の', '夢', 'は', '先生', 'に', 'な', 'る', 'こと', 'だ', '。']
# bleu: 0.9234732618882052
#
# text_no: 186
# 元の文: ['they', 'made', 'him', 'work', 'from', 'morning', 'till', 'night', '.']
# 正解文: ['彼', 'ら', 'は', '朝', 'から', '晩', 'まで', '彼', 'を', '働', 'か', 'せ', 'た', '。']
# 生成文: ['彼', 'ら', 'は', '朝', 'から', '彼', 'を', '訪ね', 'て', 'い', 'た', '。']
# bleu: 0.8739351325046805
#
# text_no: 187
# 元の文: ['she', 'wore', 'a', 'beautiful', 'dress', '.']
# 正解文: ['彼女', 'は', '美し', 'い', 'ドレス', 'を', '着', 'た', '。']
# 生成文: ['彼女', 'は', '美し', 'い', 'ドレス', 'を', '着', 'て', 'い', 'た', '。']
# bleu: 0.8593887047640296
#
# text_no: 188
# 元の文: ['it', 'is', 'sunday', 'tomorrow', '.']
# 正解文: ['明日', 'は', '日', '曜', '日', 'で', 'す', '。']
# 生成文: ['明日', 'の', '日曜', '日', 'は', '晴れ', 'て', 'い', 'る', '。']
# bleu: 0.7400828044922853
#
# text_no: 189
# 元の文: ['can', 'i', 'hang', 'out', 'here', 'till', 'seven', '?']
# 正解文: ['７', '時', 'まで', 'ここ', 'に', 'お', '邪魔', 'し', 'て', 'い', 'て', 'い', 'い', 'か', 'い', '？']
# 生成文: ['ここ', 'へ', '歩', 'い', 'て', 'くる', 'よ', '。']
# bleu: 0.7071067811865476
#
# text_no: 190
# 元の文: ['do', 'you', 'mind', 'my', 'turning', 'on', 'the', 'radio', '?']
# 正解文: ['ラジオ', 'を', 'つけ', 'て', 'も', 'い', 'い', 'で', 'す', 'か', '。']
# 生成文: ['ラジオ', 'の', '音', 'を', '小さ', 'く', 'し', 'て', 'くれ', 'ま', 'せ', 'ん', 'か', '。']
# bleu: 0.7311104457090247
#
# text_no: 191
# 元の文: ['i', 'found', 'this', 'book', 'very', 'difficult', '.']
# 正解文: ['私', 'は', 'この', '本', 'が', 'たいへん', '難し', 'い', 'と', 'わか', 'っ', 'た', '。']
# 生成文: ['この', '本', 'は', 'とても', '難し', 'い', 'と', '思', 'っ', 'た', '。']
# bleu: 0.8931539818068694
#
# text_no: 192
# 元の文: ['have', 'you', 'ever', 'written', 'a', 'book', '?']
# 正解文: ['本', 'を', '書', 'い', 'た', 'こと', 'が', 'あ', 'り', 'ま', 'す', 'か', '。']
# 生成文: ['あなた', 'は', 'もう', 'その', '本', 'を', '持', 'っ', 'て', 'い', 'ま', 'す', 'か', '。']
# bleu: 0.8408964152537145
#
# text_no: 193
# 元の文: ['since', 'you', 'say', 'so', '.']
# 正解文: ['君', 'が', 'そう', '言', 'う', 'ん', 'だ', 'から', '。']
# 生成文: ['そう', '言', 'う', 'まで', 'に', 'は', '、', 'お', '風呂', 'に', 'かか', 'り', 'なさ', 'い', '。']
# bleu: 0.668740304976422
#
# text_no: 194
# 元の文: ['i', 'received', 'a', 'letter', 'from', 'my', 'friend', '.']
# 正解文: ['友人', 'から', '手紙', 'を', 'もら', 'っ', 'た', '。']
# 生成文: ['私', 'は', '手紙', 'から', '手紙', 'を', 'もら', 'っ', 'た', '。']
# bleu: 0.7952707287670506
#
# text_no: 195
# 元の文: ['i', 'almost', 'always', 'play', 'baseball', 'after', 'school', '.']
# 正解文: ['僕', 'は', '放課', '後', 'に', 'は', 'たいてい', '野球', 'を', 'する', '。']
# 生成文: ['私', 'は', 'いつ', 'も', '野球', 'の', '日曜', '日', 'に', '野球', 'を', 'し', 'ま', 'す', '。']
# bleu: 0.7598356856515925
#
# text_no: 196
# 元の文: ['he', 'made', 'me', 'a', 'new', 'suit', '.']
# 正解文: ['彼', 'は', '私', 'に', 'スーツ', 'を', '作', 'っ', 'て', 'くれ', 'た', '。']
# 生成文: ['彼', 'は', '私', 'に', '新し', 'い', '服', 'を', '作', 'っ', 'て', 'くれ', 'た', '。']
# bleu: 0.9193227152249185
#
# text_no: 197
# 元の文: ['he', 'is', 'in', 'the', 'habit', 'of', 'taking', 'a', 'walk', 'before', 'breakfast', '.']
# 正解文: ['彼', 'は', '朝食', '前', 'に', '散歩', 'する', 'こと', 'に', 'し', 'て', 'い', 'る', '。']
# 生成文: ['彼', 'は', '朝食', '前', 'に', '散歩', 'する', 'の', 'を', '楽しみ', 'で', 'す', '。']
# bleu: 0.8242367502646054
#
# text_no: 198
# 元の文: ['be', 'quiet', ',', 'all', 'of', 'you', '.']
# 正解文: ['全員', '静か', 'に', 'し', 'なさ', 'い', '。']
# 生成文: ['静か', 'に', 'し', 'なさ', 'い', '。', '、', '静か', 'に', 'し', 'なさ', 'い', '。']
# bleu: 0.7447819789879647
#
# text_no: 199
# 元の文: ['i', 'usually', 'got', 'up', 'at', 'five', 'in', 'those', 'days', '.']
# 正解文: ['私', 'は', 'その', '当時', 'たいてい', '５', '時', 'に', '起き', 'た', '。']
# 生成文: ['私', 'は', '普通', 'は', '５', '時', 'に', '学校', 'に', '着', 'い', 'て', 'い', 'る', '。']
# bleu: 0.28495577603220296
#
# text_no: 200
# 元の文: ['we', 'may', 'as', 'well', 'set', 'to', 'work', 'at', 'once', '.']
# 正解文: ['すぐ', '仕事', 'に', '取りかか', 'っ', 'た', '方', 'が', 'い', 'い', 'だ', 'ろ', 'う', '。']
# 生成文: ['すぐ', 'に', '仕事', 'が', 'うま', 'く', 'い', 'く', 'で', 'しょ', 'う', '。']
# bleu: 0.8034284189446518
# /usr/local/lib/python3.5/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# text_no: 201
# 元の文: ['i', 'don', "'t", 'have', 'much', 'money', '.']
# 正解文: ['私', 'は', 'たい', 'し', 'て', 'お', '金', 'を', '持', 'っ', 'て', 'い', 'ま', 'せ', 'ん', '。']
# 生成文: ['金', 'は', 'あまり', 'な', 'く', 'て', 'は', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 202
# 元の文: ['i', 'never', 'see', 'this', 'picture', 'without', 'thinking', 'of', 'him', '.']
# 正解文: ['この', '写真', 'を', '見', 'る', 'と', 'いつ', 'も', '彼', 'を', '思い出', 'す', '。']
# 生成文: ['この', '絵', 'を', '見', 'る', 'と', '彼', 'を', '思い出', 'す', '。']
# bleu: 0.8931539818068694
#
# text_no: 203
# 元の文: ['he', 'is', 'anxious', 'for', 'her', 'to', 'come', '.']
# 正解文: ['彼', 'は', '彼女', 'が', '来る', '事', 'を', '切望', 'し', 'て', 'い', 'る', '。']
# 生成文: ['彼', 'は', '彼女', 'が', '来る', 'の', 'を', '楽しみ', 'だ', 'と', '思', 'っ', 'て', 'い', 'る', '。']
# bleu: 0.8408964152537145
#
# text_no: 204
# ...
# 生成文: ['君', 'の', '提案', 'は', '決して', '満足', 'し', 'て', 'い', 'な', 'かっ', 'た', '。']
# bleu: 0.8242367502646054
#
# text_no: 933
# 元の文: ['i', 'wondered', 'if', 'i', 'could', 'do', 'such', 'a', 'thing', '.']
# 正解文: ['私', 'は', '自分', 'に', 'そんな', '事', 'が', 'でき', 'る', 'かしら', 'と', '思', 'っ', 'た', '。']
# 生成文: ['そんな', 'こと', 'は', 'し', 'な', 'い', 'こと', 'に', '決め', 'た', '。']
# bleu: 0.8593887047640296
#
# text_no: 934
# 元の文: ['every', 'time', 'i', 'read', 'this', 'novel', ',', 'i', 'find', 'it', 'very', 'interesting', '.']
# 正解文: ['この', '小説', 'は', '読', 'む', 'たび', 'ごと', 'に', '実', 'に', 'おもしろ', 'い', 'と', '思', 'う', '。']
# 生成文: ['この', '小説', 'を', '読', 'ん', 'だ', 'も', '、', '彼', 'は', '三', '日', '中', 'だ', '。']
# bleu: 0.7186082239261684
#
# text_no: 935
# 元の文: ['can', 'his', 'story', 'be', 'true', '?']
# 正解文: ['一体', '彼', 'の', '話', 'は', '本当', 'だ', 'ろ', 'う', 'か', '。']
# 生成文: ['彼', 'の', '話', 'は', '本当', 'か', 'な', '。']
# bleu: 0.9306048591020996
#
# text_no: 936
# 元の文: ['she', 'makes', 'it', 'a', 'rule', 'to', 'get', 'up', 'at', 'six', 'every', 'morning', '.']
# 正解文: ['彼女', 'は', '毎朝', '６', '時', 'に', '起き', 'る', 'こと', 'に', 'し', 'て', 'い', 'る', '。']
# 生成文: ['彼女', 'は', '毎朝', '６', '時', 'に', '起き', 'る', 'こと', 'に', 'し', 'て', 'い', 'る', '。']
# bleu: 0.8801117367933934
#
# text_no: 937
# 元の文: ['my', 'son', 'took', 'a', 'candy', 'from', 'the', 'box', '.']
# 正解文: ['息子', 'は', '箱', 'から', '飴', 'を', '一', 'つ', '取', 'っ', 'た', '。']
# 生成文: ['息子', 'に', '新し', 'い', 'コンピューター', 'を', '作', 'っ', 'て', 'き', 'た', '。']
# bleu: 0.7598356856515925
#
# text_no: 938
# 元の文: ['she', 'seems', 'to', 'be', 'fond', 'of', 'talking', 'about', 'herself', '.']
# 正解文: ['彼女', 'は', '自分', 'の', 'こと', 'を', '話', 'す', 'の', 'が', '好き', 'ら', 'しい', '。']
# 生成文: ['彼女', 'は', '話', 'し', '方', 'を', '知', 'ら', 'な', 'い', 'よう', 'だ', '。']
# bleu: 0.8566209113168688
#
# text_no: 939
# 元の文: ['do', 'you', 'have', 'a', 'double', 'room', '?']
# 正解文: ['２人', '部屋', 'は', 'あ', 'り', 'ま', 'す', 'か', '。']
# 生成文: ['あなた', 'は', '部屋', 'の', '部屋', 'が', 'あ', 'り', 'ま', 'す', 'か', '。']
# bleu: 0.8739351325046805
#
# text_no: 940
# 元の文: ['her', 'hands', 'are', 'never', 'still', '.']
# 正解文: ['彼女', 'の', '手', 'は', 'うご', 'き', 'っぱなし', 'だ', '。']
# 生成文: ['彼女', 'は', 'まだ', 'まだ', 'の', 'こと', 'を', 'し', 'て', 'い', 'る', '。']
# bleu: 0.7598356856515925
#
# text_no: 941
# 元の文: ['never', 'play', 'on', 'the', 'road', '.']
# 正解文: ['絶対', 'に', '道路', 'で', '遊', 'ぶ', 'な', '。']
# 生成文: ['道路', 'を', '見', 'る', 'の', 'は', 'やめ', 'られ', 'な', 'い', '。']
# bleu: 0.6529942057256104
#
# text_no: 942
# 元の文: ['i', 'am', 'a', 'bit', 'drunk', '.']
# 正解文: ['私', 'は', '少し', '酔', 'っ', 'て', 'い', 'る', '。']
# 生成文: ['私', 'は', '少し', 'マイル', 'い', 'る', '。']
# bleu: 0.9193227152249185
#
# text_no: 943
# 元の文: ['i', 'haven', "'t", 'heard', 'from', 'him', 'since', 'then', '.']
# 正解文: ['その', '時', '以来', '彼', 'から', '何', 'の', '便り', 'も', 'な', 'い', '。']
# 生成文: ['その', '時', '以来', '彼', 'から', '便り', 'が', 'な', 'い', '。']
# bleu: 0.8408964152537145
#
# text_no: 944
# 元の文: ['i', 'am', 'writing', 'a', 'letter', '.']
# 正解文: ['私', 'は', '手紙', 'を', '書', 'い', 'て', 'い', 'る', 'ところ', 'で', 'す', '。']
# 生成文: ['私', 'は', '手紙', 'を', '書', 'い', 'て', 'い', 'ま', 'す', '。']
# bleu: 0.9234732618882052
#
# text_no: 945
# 元の文: ['is', 'this', 'dress', 'wash-able', '?']
# 正解文: ['この', 'ドレス', 'は', '水洗い', 'が', 'でき', 'ま', 'す', 'か', '。']
# 生成文: ['この', 'ドレス', 'は', 'いくら', 'で', 'す', 'か', '。']
# bleu: 0.8891397050194614
#
# text_no: 946
# 元の文: ['his', 'room', 'was', 'in', 'disorder', '.']
# 正解文: ['彼', 'の', '部屋', 'は', '散らか', 'っ', 'て', 'い', 'た', '。']
# 生成文: ['彼', 'の', '部屋', 'は', 'ほとんど', 'な', 'い', '。']
# bleu: 0.8891397050194614
#
# text_no: 947
# 元の文: ['he', 'made', 'a', 'grave', 'mistake', '.']
# 正解文: ['彼', 'は', '重大', 'な', '間違い', 'を', '起こ', 'し', 'た', '。']
# 生成文: ['彼', 'は', '間違い', 'を', 'し', 'た', '。']
# bleu: 0.9621954581957615
#
# text_no: 948
# 元の文: ['why', 'did', 'i', 'do', 'that', '?']
# 正解文: ['なぜ', '私', 'は', 'あんな', 'こと', 'を', 'し', 'た', 'の', 'か', '。']
# 生成文: ['どう', 'し', 'て', 'そんな', 'に', '、', 'それ', 'を', 'し', 'た', 'の', 'だ', 'ろ', 'う', '。']
# bleu: 0.7598356856515925
#
# text_no: 949
# 元の文: ['he', 'got', 'hurt', 'in', 'the', 'game', 'yesterday', '.']
# 正解文: ['彼', 'は', '昨日', 'の', '試合', 'で', 'けが', 'を', 'し', 'た', '。']
# 生成文: ['彼', 'は', '昨日', 'の', '試合', 'を', '見', 'た', '。']
# bleu: 0.9036020036098448
#
# text_no: 950
# 元の文: ['don', "'t", 'get', 'so', 'carried', 'away', '.']
# 正解文: ['調子', 'に', '乗り', 'すぎ', 'る', 'な', 'よ', '。']
# 生成文: ['そんな', 'に', '注意', 'し', 'て', 'は', 'いけ', 'な', 'い', '。']
# bleu: 0.7400828044922853
#
# text_no: 951
# 元の文: ['when', 'do', 'you', 'usually', 'get', 'up', '?']
# 正解文: ['朝', 'は', '普通', '何', '時', 'に', '起き', 'ま', 'す', 'か', '。']
# 生成文: ['いつ', 'も', 'いつ', 'も', '好き', 'で', 'す', 'か', '。']
# bleu: 0.7598356856515925
#
# text_no: 952
# 元の文: ['all', 'you', 'have', 'to', 'do', 'is', 'to', 'take', 'care', 'of', 'yourself', '.']
# 正解文: ['君', 'は', '体', 'に', '気', 'を', '付け', 'さえ', 'すれ', 'ば', 'い', 'い', 'よ', '。']
# 生成文: ['君', 'は', '自分', 'の', 'ため', 'に', '助け', 'る', 'こと', 'が', 'でき', 'る', '。']
# bleu: 0.7447819789879647
#
# text_no: 953
# 元の文: ['they', 'defended', 'their', 'country', '.']
# 正解文: ['彼', 'ら', 'は', '祖国', 'を', '守', 'っ', 'た', '。']
# 生成文: ['彼', 'ら', 'は', '彼', 'を', '愛', 'し', 'て', 'い', 'る', '。']
# bleu: 0.8210967436686386
#
# text_no: 954
# 元の文: ['it', 'is', 'very', 'kind', 'of', 'you', 'to', 'invite', 'me', 'to', 'the', 'party', '.']
# 正解文: ['私', 'を', 'その', 'パーティー', 'に', '招待', 'し', 'て', 'くださ', 'っ', 'て', '本当', 'に', 'ありがとう', '。']
# 生成文: ['パーティー', 'に', 'は', '私', 'の', '親切', 'に', 'あ', 'り', 'ま', 'しょ', 'う', '。']
# bleu: 0.46024953713619404
#
# text_no: 955
# 元の文: ['he', 'was', 'told', 'to', 'stand', 'up', ',', 'and', 'he', 'did', 'so', 'slowly', '.']
# 正解文: ['彼', 'は', '立ち上', 'る', 'よう', 'に', '言', 'わ', 'れ', '、', 'ゆっくり', 'と', 'そう', 'し', 'た', '。']
# 生成文: ['彼', 'は', 'ゆっくり', 'と', '言', 'っ', 'た', 'だけ', 'で', '、', 'その', '掃除', 'を', 'し', 'た', '。']
# bleu: 0.8660254037844387
#
# text_no: 956
# 元の文: ['i', "'m", 'studying', 'the', 'japanese', 'drama', '.']
# 正解文: ['私', 'は', '日本', '演劇', 'を', '勉強', 'し', 'て', 'い', 'ま', 'す', '。']
# 生成文: ['私', 'は', '日本', '語', 'を', '勉強', 'し', 'て', 'い', 'ま', 'す', '。']
# bleu: 0.9306048591020996
#
# text_no: 957
# 元の文: ['she', 'ended', 'up', 'getting', 'married', 'to', 'him', '.']
# 正解文: ['彼女', 'は', '結局', '彼', 'と', '結婚', 'する', 'こと', 'に', 'な', 'っ', 'た', '。']
# 生成文: ['彼女', 'は', '彼', 'と', '結婚', 'する', 'ため', 'に', '結婚', 'し', 'た', '。']
# bleu: 0.8408964152537145
#
# text_no: 958
# 元の文: ['i', 'have', 'been', 'to', 'the', 'station', 'to', 'see', 'him', 'off', '.']
# 正解文: ['彼', 'を', '見送り', 'に', '駅', 'へ', '行', 'っ', 'て', '来', 'た', 'ところ', 'で', 'す', '。']
# 生成文: ['彼', 'を', '見送り', 'に', '駅', 'まで', '行', 'っ', 'て', 'き', 'た', 'ところ', 'だ', '。']
# bleu: 0.8954237688029468
#
# text_no: 959
# 元の文: ['he', 'brought', 'his', 'lunch', 'today', '.']
# 正解文: ['彼', 'は', '今日', '、', 'お', '弁当', 'を', '持', 'っ', 'て', '来', 'た', '。']
# 生成文: ['彼', 'は', '今日', 'は', '昼食', 'を', 'と', 'っ', 'た', '。']
# bleu: 0.8801117367933934
#
# text_no: 960
# 元の文: ['what', 'an', 'interesting', 'book', 'this', 'is', '!']
# 正解文: ['これ', 'は', 'なん', 'と', '面白', 'い', '本', 'で', 'しょ', 'う', '。']
# 生成文: ['これ', 'は', '何', 'と', '何', '本', 'か', 'の', '物', 'だ', '。']
# bleu: 0.7765453555044466
#
# text_no: 961
# 元の文: ['in', 'his', 'business', 'he', 'cannot', 'do', 'without', 'a', 'car', '.']
# 正解文: ['彼', 'の', '仕事', 'は', '車', 'なし', 'で', 'は', 'や', 'っ', 'て', 'いけ', 'な', 'い', '。']
# 生成文: ['彼', 'の', '仕事', 'は', '仕事', 'に', 'は', 'な', 'い', '。']
# bleu: 0.8801117367933934
#
# text_no: 962
# 元の文: ['i', 'am', 'not', 'content', 'with', 'what', 'i', 'am', '.']
# 正解文: ['今', 'の', '自分', 'に', 'は', '満足', 'し', 'て', 'い', 'な', 'い', '。']
# 生成文: ['私', 'は', '自分', 'の', '考え', 'に', 'は', '何', 'も', 'な', 'ら', 'な', 'い', '。']
# bleu: 0.8091067115702212
#
# text_no: 963
# 元の文: ['don', "'t", 'forget', 'to', 'mail', 'this', 'letter', '.']
# 正解文: ['忘れ', 'ず', 'に', 'この', '手紙', 'を', '出', 'し', 'て', 'くださ', 'い', '。']
# 生成文: ['この', '手紙', 'を', '忘れ', 'ず', 'に', '必ず', '電話', 'し', 'て', 'くださ', 'い', '。']
# bleu: 0.8566209113168688
#
# text_no: 964
# 元の文: ['is', 'there', 'a', 'parking', 'lot', '?']
# 正解文: ['駐車', '場', 'は', '、', 'あ', 'り', 'ま', 'す', 'か', '。']
# 生成文: ['そこ', 'に', 'は', 'たくさん', 'い', 'ま', 'す', 'か', '。']
# bleu: 0.8633400213704505
#
# text_no: 965
# 元の文: ['i', 'have', 'much', 'to', 'do', '.']
# 正解文: ['僕', 'は', '忙し', 'い', '。']
# 生成文: ['私', 'は', 'や', 'り', 'やす', 'い', '。']
# bleu: 0.8091067115702212
#
# text_no: 966
# 元の文: ['they', 'have', 'much', 'snow', 'in', 'niigata', '.']
# 正解文: ['新潟', 'は', '雪', 'が', '多', 'い', '。']
# 生成文: ['彼', 'ら', 'は', '雪', 'が', '多', 'い', '。']
# bleu: 0.9306048591020996
#
# text_no: 967
# 元の文: ['the', 'weather', 'stayed', 'fine', 'for', 'three', 'days', '.']
# 正解文: ['三', '日間', '晴れ', 'が', '続', 'い', 'た', '。']
# 生成文: ['天気', 'は', '３', '日間', 'も', 'よ', 'い', '天気', 'だっ', 'た', '。']
# bleu: 0.7226568811456053
#
# text_no: 968
# 元の文: ['would', 'you', 'please', 'tell', 'me', 'the', 'way', 'to', 'the', 'station', '?']
# 正解文: ['駅', 'へ', '行', 'く', '道', 'を', '教え', 'て', '下さ', 'い', 'ま', 'せ', 'ん', 'か', '。']
# 生成文: ['駅', 'へ', '行', 'く', '道', 'を', '教え', 'て', 'くださ', 'い', '。']
# bleu: 0.9510699415570292
#
# text_no: 969
# 元の文: ['the', 'captain', 'told', 'us', 'to', 'get', 'off', 'the', 'ship', '.']
# 正解文: ['船長', 'は', '私', '達', 'に', '船', 'を', '降り', 'る', 'よう', 'に', '言', 'っ', 'た', '。']
# 生成文: ['その', '男', 'は', '我々', 'を', '出発', 'する', 'の', 'を', 'やめ', 'た', '。']
# bleu: 0.7598356856515925
#
# text_no: 970
# 元の文: ['his', 'death', 'was', 'great', 'shock', 'to', 'his', 'wife', '.']
# 正解文: ['彼', 'の', '死', 'は', '妻', 'に', 'と', 'っ', 'て', 'あまり', 'に', 'も', 'ショック', 'だっ', 'た', '。']
# 生成文: ['彼', 'の', '死', 'は', '妻', 'に', 'は', '死', 'ん', 'だ', '。']
# bleu: 0.9234732618882052
#
# text_no: 971
# 元の文: ['he', 'has', 'a', 'loud', 'voice', '.']
# 正解文: ['彼', 'は', '声', 'が', '大き', 'い', '。']
# 生成文: ['彼', 'は', '声', 'が', 'あ', 'る', '。']
# bleu: 0.9193227152249185
#
# text_no: 972
# 元の文: ['he', 'gave', 'an', 'account', 'of', 'his', 'trip', '.']
# 正解文: ['彼', 'は', '旅行', 'の', '話', 'を', 'し', 'た', '。']
# 生成文: ['彼', 'は', '旅行', 'の', 'ため', 'に', '旅行', 'を', 'し', 'た', '。']
# bleu: 0.8931539818068694
#
# text_no: 973
# 元の文: ['i', 'wonder', 'if', 'it', 'will', 'rain', 'tomorrow', '.']
# 正解文: ['明日', 'は', '雨', 'が', '降', 'る', 'かしら', '。']
# 生成文: ['明日', 'は', '雨', 'が', '降', 'る', 'だ', 'ろ', 'う', '。']
# bleu: 0.8801117367933934
#
# text_no: 974
# 元の文: ['he', 'could', 'not', 'believe', 'his', 'eyes', '.']
# 正解文: ['彼', 'は', '自分', 'の', '目', 'を', '信じ', 'る', 'こと', 'が', 'でき', 'な', 'かっ', 'た', '。']
# 生成文: ['彼', 'は', '自分', 'の', '目', 'を', '信', 'じ', 'られ', 'な', 'かっ', 'た', '。']
# bleu: 0.5031747626530138
#
# text_no: 975
# 元の文: ['talking', 'of', 'music', ',', 'what', 'kind', 'of', 'music', 'do', 'you', 'like', '?']
# 正解文: ['音楽', 'と', 'い', 'え', 'ば', '、', '君', 'は', 'どんな', '音楽', 'が', 'すき', 'な', 'の', '。']
# 生成文: ['音楽', 'の', '中', 'で', 'お', '話', 'し', 'ま', 'す', 'か', '。']
# bleu: 0.7226568811456053
#
# text_no: 976
# 元の文: ['part', 'of', 'his', 'story', 'is', 'true', '.']
# 正解文: ['彼', 'の', '話', 'の', '一部', 'は', '本当', 'だ', '。']
# 生成文: ['彼', 'の', '話', 'は', '本当', 'に', 'な', 'の', 'だ', '。']
# bleu: 0.8801117367933934
#
# text_no: 977
# 元の文: ['he', 'turned', 'over', 'the', 'business', 'to', 'his', 'son', '.']
# 正解文: ['彼', 'の', '事業', 'を', '息子', 'に', '譲', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '息子', 'を', '自分', 'の', 'ため', 'に', '事業', 'に', '失敗', 'し', 'た', '。']
# bleu: 0.8091067115702212
#
# text_no: 978
# 元の文: ['it', 'feels', 'like', 'i', "'ve", 'seen', 'her', 'before', '.']
# 正解文: ['以前', '、', '彼女', 'に', '会', 'っ', 'た', 'よう', 'な', '気', 'が', 'する', '。']
# 生成文: ['彼女', 'に', '会', 'っ', 'た', 'こと', 'は', 'もう', '引き受け', 'て', 'い', 'ま', 'す', '。']
# bleu: 0.8091067115702212
#
# text_no: 979
# 元の文: ['you', 'should', 'put', 'something', 'in', 'your', 'stomach', 'before', 'you', 'go', '.']
# 正解文: ['何', 'か', 'おなか', 'に', '入れ', 'て', 'から', '出かけ', 'な', 'さ', 'い', '。']
# 生成文: ['出かけ', 'る', '前', 'に', 'もっと', '注意', 'を', 'し', 'た', 'ほう', 'が', 'い', 'い', '。']
# bleu: 0.6803749333171202
#
# text_no: 980
# 元の文: ['start', 'this', 'moment', '.']
# 正解文: ['今', 'すぐ', '出発', 'し', 'なさ', 'い', '。']
# 生成文: ['今晩', '、', 'お', '電話', 'を', 'し', 'て', 'しま', 'い', 'ま', 'し', 'た', '。']
# bleu: 0.6930977286178778
#
# text_no: 981
# 元の文: ['he', 'went', 'in', 'place', 'of', 'me', '.']
# 正解文: ['彼', 'が', '私', 'の', '代わり', 'に', '行', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '私', 'の', '手', 'に', '泊ま', 'っ', 'た', '。']
# bleu: 0.9146912192286945
#
# text_no: 982
# 元の文: ['he', 'asked', 'a', 'question', 'about', 'it', '.']
# 正解文: ['彼', 'は', 'それ', 'に', 'つ', 'い', 'て', '質問', 'し', 'た', '。']
# 生成文: ['彼', 'は', 'その', '問題', 'を', '解', 'い', 'て', 'くれ', 'た', '。']
# bleu: 0.8593887047640296
#
# text_no: 983
# 元の文: ['i', 'suppose', 'he', "'s", 'gone', 'home', '.']
# 正解文: ['彼', 'は', '帰宅', 'し', 'た', 'と', '私', 'は', '思', 'う', '。']
# 生成文: ['彼', 'は', '家', 'に', '帰', 'っ', 'て', 'き', 'た', 'の', 'だ', '。']
# bleu: 0.8034284189446518
#
# text_no: 984
# 元の文: ['it', "'s", 'a', 'matter', 'of', 'cost', '.']
# 正解文: ['それ', 'は', '費用', 'の', '問題', 'だ', '。']
# 生成文: ['それ', 'は', '重要', 'な', 'もの', 'だ', '。']
# bleu: 0.8091067115702212
#
# text_no: 985
# 元の文: ['the', 'old', 'man', 'walked', 'across', 'the', 'road', 'carefully', '.']
# 正解文: ['その', '老人', 'は', '道路', 'を', '注意', '深', 'く', '横断', 'し', 'た', '。']
# 生成文: ['老人', 'は', '老人', 'が', '道', 'を', '道', 'に', '行', 'っ', 'た', '。']
# bleu: 0.8034284189446518
#
# text_no: 986
# 元の文: ['can', 'i', 'speak', 'to', 'the', 'doctor', '?']
# 正解文: ['先生', 'と', '話', 'し', 'た', 'い', 'の', 'で', 'す', 'が', '。']
# 生成文: ['医者', 'を', 'お', '知', 'ら', 'な', 'い', 'で', 'しょ', 'う', 'か', '。']
# bleu: 0.7071067811865476
#
# text_no: 987
# 元の文: ['i', 'bought', 'a', 'camera', 'two', 'days', 'ago', '.']
# 正解文: ['私', 'は', '二', '日', '前', 'に', 'カメラ', 'を', '買', 'っ', 'た', '。']
# 生成文: ['私', 'は', '一', '週間', '前', 'に', 'カメラ', 'を', '買', 'っ', 'た', '。']
# bleu: 0.9306048591020996
#
# text_no: 988
# 元の文: ['try', 'to', 'read', 'as', 'many', 'books', 'as', 'possible', '.']
# 正解文: ['出来', 'る', 'だけ', '沢山', 'の', '本', 'を', '読', 'む', 'よう', 'に', 'し', 'なさ', 'い', '。']
# 生成文: ['本', 'を', '読', 'む', 'だけ', 'の', 'ため', 'に', '注意', 'し', 'なさ', 'い', '。']
# bleu: 0.912167909070388
#
# text_no: 989
# 元の文: ['this', 'desk', 'was', 'too', 'heavy', 'to', 'lift', '.']
# 正解文: ['この', '机', 'は', '重', 'く', 'て', '持ち上が', 'ら', 'な', 'かっ', 'た', '。']
# 生成文: ['この', '机', 'は', '２', '万', '円', 'し', 'た', '。']
# bleu: 0.816496580927726
#
# text_no: 990
# 元の文: ['she', 'is', 'muttering', 'to', 'herself', '.']
# 正解文: ['彼女', 'は', 'ひとり', 'で', 'ブツブツ', '言', 'っ', 'て', 'い', 'る', '。']
# 生成文: ['彼女', 'は', '自分', 'の', 'こと', 'を', '確信', 'し', 'て', 'い', 'る', '。']
# bleu: 0.8034284189446518
#
# text_no: 991
# 元の文: ['he', 'came', 'to', 'terms', 'with', 'her', '.']
# 正解文: ['彼', 'は', '彼女', 'と', '仲直り', 'し', 'た', '。']
# 生成文: ['彼', 'は', '彼女', 'に', '腹', 'を', '立て', 'た', '。']
# bleu: 0.816496580927726
#
# text_no: 992
# 元の文: ['on', 'account', 'of', 'an', 'accident', ',', 'i', 'was', 'late', 'for', 'school', '.']
# 正解文: ['事故', 'の', 'ため', '学校', 'に', '遅れ', 'た', '。']
# 生成文: ['私', 'が', '学校', 'に', '遅れ', 'た', 'の', 'は', '交通', '遅れ', 'た', '。']
# bleu: 0.7598356856515925
#
# text_no: 993
# 元の文: ['when', 'do', 'you', 'come', 'and', 'see', 'me', '?']
# 正解文: ['あなた', 'は', 'いつ', '私', 'に', '会', 'い', 'に', '来', 'ま', 'す', 'か', '。']
# 生成文: ['いつ', '来', 'て', 'くれ', 'ま', 'せ', 'ん', 'か', '。']
# bleu: 0.816496580927726
#
# text_no: 994
# 元の文: ['i', 'look', 'on', 'watching', 'tv', 'as', 'a', 'waste', 'of', 'time', '.']
# 正解文: ['私', 'は', 'テレビ', 'を', '見', 'る', 'こと', 'を', '時間', 'の', '無駄', 'づかい', 'と', 'みな', 'す', '。']
# 生成文: ['私', 'は', 'テレビ', 'を', '見', 'る', 'と', 'すぐ', '待', 'つ', '。']
# bleu: 0.8931539818068694
#
# text_no: 995
# 元の文: ['no', 'wonder', 'you', 'could', 'not', 'open', 'the', 'door', '.']
# 正解文: ['君', 'が', 'ドア', 'を', '開け', 'られ', 'な', 'かっ', 'た', 'の', 'も', '無理', 'は', 'な', 'い', '。']
# 生成文: ['ドア', 'を', '開け', 'て', 'は', 'いけ', 'な', 'い', '。']
# bleu: 0.8633400213704505
#
# text_no: 996
# 元の文: ['i', "'ll", 'accompany', 'you', 'to', 'the', 'station', '.']
# 正解文: ['駅', 'まで', 'お', '供', 'し', 'ま', 'しょ', 'う', '。']
# 生成文: ['私', 'は', '駅', 'まで', 'まで', 'お', '待', 'ち', 'ま', 'す', '。']
# bleu: 0.7765453555044466
#
# text_no: 997
# 元の文: ['i', 'will', 'be', 'over', 'tomorrow', 'if', 'you', 'like', '.']
# 正解文: ['よろし', 'かっ', 'たら', '明日', 'うか', 'が', 'い', 'ま', 'す', '。']
# 生成文: ['明日', 'は', '、', '私', 'が', '正し', 'く', 'て', 'い', 'る', 'で', 'しょ', 'う', '。']
# bleu: 0.7311104457090247
#
# text_no: 998
# 元の文: ['the', 'radio', 'is', 'too', 'loud', '.']
# 正解文: ['ラジオ', 'の', '音', 'が', '大き', 'すぎ', 'る', '。']
# 生成文: ['ラジオ', 'は', '少し', 'も', '開', 'い', 'て', 'い', 'る', '。']
# bleu: 0.668740304976422
#
# text_no: 999
# 元の文: ['in', 'any', 'case', ',', 'it', "'s", 'wrong', 'to', 'break', 'a', 'promise', '.']
# 正解文: ['ともかく', '約束', 'を', '破', 'る', 'の', 'は', 'よく', 'あ', 'り', 'ま', 'せ', 'ん', '。']
# 生成文: ['約束', 'が', 'あ', 'る', 'と', 'いつ', 'も', 'い', 'う', 'もの', 'は', 'あ', 'る', '。']
# bleu: 0.8091067115702212

# %%
for text_no in range(len(X_validation)):
    inp = [detokenizer_en[i] for i in X_validation[text_no][1:-1]]
    ref = [detokenizer_ja[i] for i in Y_validation[text_no][1:-1]]
    
    input_seq = pad_sequences([X_validation[text_no]], dim_seq_input, padding='post')
    pred = [detokenizer_ja[i] for i in model.predict(input_seq, bos_eos)[1:-1]]
    
    bleu = sentence_bleu(ref, pred)
    
    if bleu > 0.95:
        print('text_no: {0}'.format(text_no))
        print('元の文: {0}'.format(inp))
        print('正解文: {0}'.format(ref))
        print('生成文: {0}'.format(pred))
        print('bleu: {0}\n'.format(bleu))
# Out:
# /usr/local/lib/python3.5/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# text_no: 20
# 元の文: ['he', 'is', 'almost', 'always', 'at', 'home', '.']
# 正解文: ['彼', 'は', 'ほとんど', 'いつ', 'も', '家', 'に', 'い', 'る', '。']
# 生成文: ['彼', 'は', 'いつ', 'も', '家', 'に', 'い', 'る', '。']
# bleu: 0.9709835434146469
#
# text_no: 64
# 元の文: ['she', 'is', 'not', 'as', 'tall', 'as', 'he', '.']
# 正解文: ['彼女', 'は', '彼', 'ほど', '背', 'が', '高', 'く', 'な', 'い', '。']
# 生成文: ['彼女', 'は', '彼', 'ほど', '背', 'が', '高', 'く', 'な', 'い', '。']
# bleu: 0.9510699415570292
#
# text_no: 111
# 元の文: ['it', 'is', 'impossible', 'for', 'him', 'to', 'become', 'a', 'doctor', '.']
# 正解文: ['彼', 'が', '医者', 'に', 'な', 'る', 'の', 'は', '不', '可能', 'だ', '。']
# 生成文: ['彼', 'が', '医者', 'に', 'な', 'る', 'の', 'は', '不', '可能', 'だ', '。']
# bleu: 0.9554427922043668
#
# text_no: 127
# 元の文: ['i', "'d", 'like', 'you', 'to', 'cut', 'my', 'hair', '.']
# 正解文: ['髪', 'を', '切', 'っ', 'て', 'もら', 'い', 'た', 'い', 'ん', 'で', 'す', 'が', '。']
# 生成文: ['髪', 'を', '切', 'っ', 'て', 'ほし', 'い', 'の', 'で', 'す', 'が', '。']
# bleu: 0.9554427922043668
# /usr/local/lib/python3.5/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# text_no: 206
# 元の文: ['how', 'fast', 'he', 'can', 'run', '!']
# 正解文: ['彼', 'は', 'なん', 'と', '速', 'く', '走れ', 'る', 'の', 'で', 'しょ', 'う', '。']
# 生成文: ['彼', 'は', 'なん', 'と', '速', 'く', '走', 'る', 'の', 'で', 'しょ', 'う', '。']
# bleu: 0.9590965597935381
#
# text_no: 255
# 元の文: ['i', 'said', 'it', 'might', 'rain', '.']
# 正解文: ['雨', 'が', '降', 'る', 'か', 'も', 'しれ', 'な', 'い', 'と', '私', 'は', '言', 'っ', 'た', '。']
# 生成文: ['雨', 'が', '降', 'る', 'と', '言', 'っ', 'て', 'い', 'た', '。']
# bleu: 0.9764540896763105
#
# text_no: 267
# 元の文: ['this', 'is', 'the', 'end', 'of', 'my', 'story', '.']
# 正解文: ['これ', 'で', '私', 'の', '話', 'は', '終わり', 'で', 'す', '。']
# 生成文: ['これ', 'は', '私', 'の', '話', 'で', 'す', '。']
# bleu: 0.9671682101338347
#
# text_no: 276
# 元の文: ['may', 'i', 'borrow', 'your', 'car', '?']
# 正解文: ['自動', '車', 'を', '借り', 'て', 'も', 'い', 'い', 'で', 'す', 'か', '。']
# 生成文: ['車', 'を', '借り', 'て', 'も', 'い', 'い', 'で', 'す', 'か', '。']
# bleu: 0.9510699415570292
# /usr/local/lib/python3.5/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# text_no: 341
# 元の文: ['will', 'it', 'rain', 'tomorrow', '?']
# 正解文: ['明日', 'は', '雨', 'が', '降', 'る', 'で', 'しょ', 'う', 'か', '。']
# 生成文: ['明日', 'は', '雨', 'が', '降', 'る', 'で', 'しょ', 'う', 'か', '。']
# bleu: 0.9510699415570292
#
# text_no: 377
# 元の文: ['he', 'hit', 'me', 'on', 'the', 'head', '.']
# 正解文: ['彼', 'は', '僕', 'の', '頭', 'を', '殴', 'っ', 'た', '。']
# 生成文: ['彼', 'は', '私', 'の', '頭', 'を', '殴', 'っ', 'た', '。']
# bleu: 0.9740037464252967
#
# text_no: 400
# 元の文: ['i', 'like', 'dogs', '.']
# 正解文: ['私', 'は', '、', '犬', 'が', '好き', 'で', 'す', '。']
# 生成文: ['私', 'は', '犬', 'が', '好き', 'で', 'す', '。']
# bleu: 0.9671682101338347
#
# text_no: 419
# 元の文: ['we', 'made', 'him', 'go', '.']
# 正解文: ['私', 'たち', 'は', '彼', 'を', '行', 'か', 'せ', 'た', '。']
# 生成文: ['私', 'たち', 'は', '彼', 'を', '行', 'か', 'せ', 'た', '。']
# bleu: 0.9740037464252967
#
# text_no: 471
# 元の文: ['it', 'is', 'no', 'use', 'your', 'pretending', 'that', 'you', 'know', 'nothing', '.']
# 正解文: ['何', 'も', '知', 'ら', 'な', 'い', 'ふり', 'を', 'し', 'て', 'も', '無駄', 'だ', '。']
# 生成文: ['君', 'が', '何', 'を', 'し', 'て', 'も', '知', 'ら', 'な', 'い', '。']
# bleu: 0.9554427922043668
#
# text_no: 516
# 元の文: ['i', 'had', 'a', 'bad', 'dream', 'last', 'night', '.']
# 正解文: ['私', 'は', '昨晩', '悪', 'い', '夢', 'を', '見', 'ま', 'し', 'た', '。']
# 生成文: ['私', 'は', '昨夜', '夢', 'を', '見', 'ま', 'し', 'た', '。']
# bleu: 0.9740037464252967
#
# text_no: 556
# 元の文: ['my', 'car', 'is', 'a', 'toyota', '.']
# 正解文: ['私', 'の', '車', 'は', 'トヨタ', 'の', '車', 'で', 'す', '。']
# 生成文: ['私', 'の', '車', 'は', 'どこ', 'で', 'す', '。']
# bleu: 0.9671682101338347
#
# text_no: 585
# 元の文: ['he', 'has', 'three', 'times', 'as', 'many', 'books', 'as', 'i', 'have', '.']
# 正解文: ['彼', 'は', '私', 'の', '三', '倍', '本', 'を', '持', 'っ', 'て', 'い', 'る', '。']
# 生成文: ['彼', 'は', '私', 'の', '本', 'を', '３', '冊', '持', 'っ', 'て', 'い', 'る', '。']
# bleu: 0.9621954581957615
#
# text_no: 608
# 元の文: ['i', 'am', 'a', 'high', 'school', 'student', '.']
# 正解文: ['私', 'は', '高校', '生', 'で', 'す', '。']
# 生成文: ['私', 'は', '高校', '生', 'で', 'す', '。']
# bleu: 0.9621954581957615
#
# text_no: 612
# 元の文: ['i', 'put', 'handcuffs', 'on', 'him', '.']
# 正解文: ['私', 'は', '彼', 'に', '手錠', 'を', 'かけ', 'た', '。']
# 生成文: ['彼', 'に', 'は', '手', 'を', '止め', 'た', '。']
# bleu: 0.9671682101338347
#
# text_no: 625
# 元の文: ['i', 'am', 'afraid', 'that', 'it', 'will', 'rain', '.']
# 正解文: ['雨', 'が', '降り', 'は', 'し', 'な', 'い', 'か', 'と', '思', 'う', '。']
# 生成文: ['雨', 'が', '降', 'る', 'と', '思', 'う', '。']
# bleu: 0.9671682101338347
#
# text_no: 637
# 元の文: ['he', 'is', 'studying', 'agriculture', '.']
# 正解文: ['彼', 'は', '農業', 'の', '研究', 'を', 'し', 'て', 'い', 'る', '。']
# 生成文: ['彼', 'は', '勉強', 'を', 'し', 'て', 'い', 'る', '。']
# bleu: 0.9709835434146469
#
# text_no: 727
# 元の文: ['he', 'came', 'back', 'after', 'two', 'hours', '.']
# 正解文: ['彼', 'は', '２', '時間', '後', 'に', '戻', 'っ', 'て', 'き', 'た', '。']
# 生成文: ['彼', 'は', '２', '時間', '後', 'に', '帰', 'っ', 'て', 'き', 'た', '。']
# bleu: 0.9554427922043668
#
# text_no: 736
# 元の文: ['please', 'put', 'out', 'the', 'light', 'before', 'you', 'go', 'to', 'sleep', '.']
# 正解文: ['寝', 'る', '前', 'に', 'は', '明かり', 'を', '消', 'し', 'て', '下さ', 'い', '。']
# 生成文: ['寝', 'る', '前', 'に', '明かり', 'を', '消', 'し', 'なさ', 'い', '。']
# bleu: 0.9510699415570292
#
# text_no: 824
# 元の文: ['does', 'she', 'speak', 'french', '?']
# 正解文: ['彼女', 'は', 'フランス', '語', 'を', '話', 'し', 'ま', 'す', 'か', '。']
# 生成文: ['彼女', 'は', 'フランス', '語', 'を', '話', 'し', 'ま', 'す', 'か', '。']
# bleu: 0.9510699415570292
#
# text_no: 860
# 元の文: ['yesterday', 'i', 'had', 'my', 'bicycle', 'stolen', '.']
# 正解文: ['昨日', '私', 'は', '自転', '車', 'を', '盗', 'ま', 'れ', 'た', '。']
# 生成文: ['昨日', '私', 'は', '自転', '車', 'を', '盗', 'ま', 'れ', 'た', '。']
# bleu: 0.9510699415570292
#
# text_no: 947
# 元の文: ['he', 'made', 'a', 'grave', 'mistake', '.']
# 正解文: ['彼', 'は', '重大', 'な', '間違い', 'を', '起こ', 'し', 'た', '。']
# 生成文: ['彼', 'は', '間違い', 'を', 'し', 'た', '。']
# bleu: 0.9621954581957615
#
# text_no: 968
# 元の文: ['would', 'you', 'please', 'tell', 'me', 'the', 'way', 'to', 'the', 'station', '?']
# 正解文: ['駅', 'へ', '行', 'く', '道', 'を', '教え', 'て', '下さ', 'い', 'ま', 'せ', 'ん', 'か', '。']
# 生成文: ['駅', 'へ', '行', 'く', '道', 'を', '教え', 'て', 'くださ', 'い', '。']
# bleu: 0.9510699415570292
